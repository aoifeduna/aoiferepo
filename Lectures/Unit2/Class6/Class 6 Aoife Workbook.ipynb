# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/aoifeduna/AoifeRepo/aoiferepo/Lectures/Unit2/data/titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df.value_counts()
# Value counts is a series method not a data frame method
# You have to select an individual column for it to work
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-1cdce306d95b> in <module>
# ----> 1 df.value_counts()
#       2 # Value counts is a series method not a data frame method
#       3 # You have to select an individual column for it to work
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
df.nunique()
# How many unique values in every single column
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
df['Embarked'].unique()
# Gives you a list of every single unique value
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df['Embarked'].unique().tolist()
# Takes unique values and puts them in a list
# Out:
# ['S', 'C', 'Q', nan]

# %%
df[['Embarked', 'Fare']].head()
# This is the shorthand for the next query
# Out:
#   Embarked     Fare
# 0        S   7.2500
# 1        C  71.2833
# 2        S   7.9250
# 3        S  53.1000
# 4        S   8.0500

# %%
df.loc[:,['Embarked', 'Fare']]
# Out:
#     Embarked     Fare
# 0          S   7.2500
# 1          C  71.2833
# 2          S   7.9250
# 3          S  53.1000
# 4          S   8.0500
# ..       ...      ...
# 886        S  13.0000
# 887        S  30.0000
# 888        S  23.4500
# 889        C  30.0000
# 890        Q   7.7500
#
# [891 rows x 2 columns]

# %%
# Took a bunch of notes in the lab from the previous week

# %%
df.sort_values('Fare', ascending=False)
# Top to bottom. Defaults to bottom to top w/o the ascending argument.
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 737          738         1       1              Lesurer, Mr. Gustave J
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 88            89         1       1          Fortune, Miss. Mabel Helen
# 27            28         0       1      Fortune, Mr. Charles Alexander
# ..           ...       ...     ...                                 ...
# 633          634         0       1       Parr, Mr. William Henry Marsh
# 413          414         0       2      Cunningham, Mr. Alfred Fleming
# 822          823         0       1     Reuchlin, Jonkheer. John George
# 732          733         0       2                Knight, Mr. Robert J
# 674          675         0       2          Watson, Mr. Ennis Hastings
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %%
# To do nested sorting, you can pass in a list of nested columns.
df.sort_values(['Sex','Fare'], ascending=False)
# Sorts all the men first and then by ticket price
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
# 27            28         0       1      Fortune, Mr. Charles Alexander
# 438          439         0       1                   Fortune, Mr. Mark
# 118          119         0       1            Baxter, Mr. Quigg Edmond
# ..           ...       ...     ...                                 ...
# 367          368         1       3      Moussa, Mrs. (Mantoura Boulos)
# 780          781         1       3                Ayoub, Miss. Banoura
# 19            20         1       3             Masselmani, Mrs. Fatima
# 875          876         1       3    Najib, Miss. Adele Kiamie "Jane"
# 654          655         0       3        Hegarty, Miss. Hanora "Nora"
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %%
sales = pd.read_excel("/Users/aoifeduna/AoifeRepo/aoiferepo/Lectures/Unit2/data/superstore.xls")

# %%
sales.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
my_dict = {
    'key': 'value',
    'key2': 'value2',
}

# %%
my_dict['key3'] = 3
# Assigning a new key value pair. Notice there's no key called key3.

# %%
my_dict
# Out:
# {'key': 'value', 'key2': 'value2', 'key3': 3}

# %%
sales['NumOne'] = 1
# Creating new columns within a dataframe is akin ot creating a new key value pair within a dictionary.

# %%
sales.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ... Region  \
# 0      Claire Gute   Consumer  United States        Henderson  ...  South
# 1      Claire Gute   Consumer  United States        Henderson  ...  South
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...   West
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
#
#         Product ID         Category Sub-Category  \
# ...

# %%
sales.drop('NumOne')
# This is going to key error because it's going down the rows.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-7a23a9c7a2bf> in <module>
# ----> 1 sales.drop('NumOne')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
# ...

# %%
sales.drop('NumOne', axis = 1)
# Now checking the columns.
# This drops the column from the display, but it doesn't change the underlying data.
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
# What if you want to permanently change the data frame?
sales = sales.drop('NumOne', axis = 1)
# This is an option

# %%
# You can also use an inplace method
sales = sales.drop('NumOne', axis = 1, inplace=True)
# I already removed the column so this is not going to work
# This is buggy. There are some edge cases where this won't work
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-1470d181d61d> in <module>
#       1 # You can also use an inplace method
# ----> 2 sales = sales.drop('NumOne', axis = 1, inplace=True)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ...

# %%
sales['Profit']/sales['Sales']
# Out:
# 0       0.1600
# 1       0.3000
# 2       0.4700
# 3      -0.4000
# 4       0.1125
#          ...
# 9989    0.1625
# 9990    0.1700
# 9991    0.0750
# 9992    0.4500
# 9993    0.3000
# Length: 9994, dtype: float64

# %%
sales['Profit Margin'] = sales['Profit']/sales['Sales']
# Basically making a new column label to keep this data goin'

# %%
sales
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
import numpy as np
sales['Profitable'] = np.where(sales['Profit'] > 0, 'Profitable', 'Not Profitable')
# Easy way to write an if then statement

# %%
sales
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
sales['Profitable'].value_counts()
# If there's a null value it's automatically false
# Out:
# Profitable        8058
# Not Profitable    1936
# Name: Profitable, dtype: int64

# %%
sales['Profitable'].dtype
# It's an object
# Out:
# dtype('O')

# %%
conditions = [
    (sales['Region'] == 'East') & (sales['Profitable'] == 'Profitable'),
    (sales['Region'] == 'East') & (sales['Profitable'] == 'Not Profitable'),
    (sales['Region'] == 'West') & (sales['Profitable'] == 'Profitable')
]

results = ['East-Profitable', 'East-Not Profitable', 'West-Profitable']

sales['RegionProfits'] = np.select(conditions, results, 'Other')
# 'Other' is the else statement
# This is by far the fastest way of evaluating if statements

# %%
sales['RegionProfits'].value_counts()
# Out:
# Other                  4283
# West-Profitable        2863
# East-Profitable        2276
# East-Not Profitable     572
# Name: RegionProfits, dtype: int64
