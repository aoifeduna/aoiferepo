# %% [markdown]
# ## Intermediate Lab:  Creating A Dataset Using the GitHub API
#
# In this lab you'll create a dataset containing all the meta information about your classmates github repos, using only the csv file with everyone's url.
#
# The process will be done in these 4 general steps:
#
#  - load in the csv file
#  - clean the individual lines of each file to get them ready to use
#  - connect to the GitHub api to obtain information about everyone's repos
#  - re-structure this information to turn it into a dataframe.
#
# It'll be a great way to work through the first step of many data science problems: creating a workable dataset out of unorganized, messy data.  Let's get started!

# %% [markdown]
# ### Step 1:  Load in the csv file with everyone's github repo
#
# **Note:** There are a number of ways to do this, but the easiest way is usually this:
#
#     `with open('file.csv') as f:
#
#         data = f.readlines()`

# %%
with open('Repos.csv') as f:
    data = f.readlines()

# %% [markdown]
# What you should have now is a list, and each item is a string that contains the comma separated values of each cell in the row of that csv file.
#
# It should generically look like this:
#
#     `['Name,Repo\n',
#       'Person 1,https://github.com/username\n',
#       'Person 2,https://github.com/username\n',
#        ......
#        ]`
#
# Double check this is the case.

# %%
data
# Out:
# ['Name,Repo\n',
#  'Jonathan Bechtel,https://github.com/JonathanBechtel\n',
#  'Aoife Duna,https://github.com/aoifeduna\n',
#  'Christos Simos,https://github.com/simoschr\n',
#  'Brittani Kauf,https://github.com/brittanikauf\n',
#  'Stanford Turner,https://github.com/sturner08\n',
#  'Shelly Seroussi,https://github.com/sturner08\n',
#  'Shela Wu,https://github.com/misowu\n',
#  'Rishabh Chandra,https://github.com/rishabhchandra35\n',
#  '"Behrang ""Brian"" Bidadi",https://github.com/brianb888\n',
#  'Alec Schneider,https://github.com/Blitz33697\n',
#  'Taku Takamatsu,https://github.com/taku-takamatsu\n',
#  'Lindsey Gumann,https://github.com/lgumann\n',
#  'David Hurley,https://github.com/davehurl\n',
#  'Kina Abe,https://github.com/kinaabe57\n',
#  'Elyse Chu,https://github.com/elysechu\n',
#  'Michael Lawlor,https://github.com/lawlormj/sample_work\n',
#  'Emily Lam,https://github.com/emilylam98\n',
#  'Mike Golodner,https://github.com/mgolodner/ga_repo.git\n',
#  'Siddharth Uppal,https://github.com/sid25393']

# %% [markdown]
# The only thing we need out of each item is the persons username, that part contained in the string at: `https://github.com/username_here`.  Everything else is junk.
#
# We'll need to go through a few steps to get our info down to a usable format.

# %% [markdown]
# ### Step 2: Remove the `\n` from each item in the list, as well as the item that contains the header info.
#
# When you're done you should have a list that looks like this:
#
#       `[
#       'Person 1,https://github.com/username',
#       'Person 2,https://github.com/username',
#        ......
#        ]`
#
# **hint:** The `replace()` method for strings is probably one of the more useful options that you have.  If you want to replace something with nothing, you can simply specify `""` for that part.

# %%
cleaneddata = [repo.replace('\n',"") for repo in data[1:]]

# %%
cleaneddata
# Out:
# ['Jonathan Bechtel,https://github.com/JonathanBechtel',
#  'Aoife Duna,https://github.com/aoifeduna',
#  'Christos Simos,https://github.com/simoschr',
#  'Brittani Kauf,https://github.com/brittanikauf',
#  'Stanford Turner,https://github.com/sturner08',
#  'Shelly Seroussi,https://github.com/sturner08',
#  'Shela Wu,https://github.com/misowu',
#  'Rishabh Chandra,https://github.com/rishabhchandra35',
#  '"Behrang ""Brian"" Bidadi",https://github.com/brianb888',
#  'Alec Schneider,https://github.com/Blitz33697',
#  'Taku Takamatsu,https://github.com/taku-takamatsu',
#  'Lindsey Gumann,https://github.com/lgumann',
#  'David Hurley,https://github.com/davehurl',
#  'Kina Abe,https://github.com/kinaabe57',
#  'Elyse Chu,https://github.com/elysechu',
#  'Michael Lawlor,https://github.com/lawlormj/sample_work',
#  'Emily Lam,https://github.com/emilylam98',
#  'Mike Golodner,https://github.com/mgolodner/ga_repo.git',
#  'Siddharth Uppal,https://github.com/sid25393']

# %% [markdown]
# ### Step 3:  Separate the url in each string from everything else
#
# When you're done you should have a new list that looks like this:
#
#     `[
#        'https://github.com/username',
#        'https://github.com/username',
#        ...
#      ]`
#
# **hint:** The `split()` method will help you out here.

# %%
repo_urls = [line.split(',')[1] for line in cleaneddata]
repo_urls
# Out:
# ['https://github.com/JonathanBechtel',
#  'https://github.com/aoifeduna',
#  'https://github.com/simoschr',
#  'https://github.com/brittanikauf',
#  'https://github.com/sturner08',
#  'https://github.com/sturner08',
#  'https://github.com/misowu',
#  'https://github.com/rishabhchandra35',
#  'https://github.com/brianb888',
#  'https://github.com/Blitz33697',
#  'https://github.com/taku-takamatsu',
#  'https://github.com/lgumann',
#  'https://github.com/davehurl',
#  'https://github.com/kinaabe57',
#  'https://github.com/elysechu',
#  'https://github.com/lawlormj/sample_work',
#  'https://github.com/emilylam98',
#  'https://github.com/mgolodner/ga_repo.git',
#  'https://github.com/sid25393']

# %% [markdown]
# ### Step 4:  Separate the username in each string from everything else
#
# When you're done you should have a new list that looks like this:
#
#     `[
#        'username1',
#        'username2',
#        ...
#      ]`

# %%
usernames = [url.split('/')[-1] for url in repo_urls]
usernames
# Out:
# ['JonathanBechtel',
#  'aoifeduna',
#  'simoschr',
#  'brittanikauf',
#  'sturner08',
#  'sturner08',
#  'misowu',
#  'rishabhchandra35',
#  'brianb888',
#  'Blitz33697',
#  'taku-takamatsu',
#  'lgumann',
#  'davehurl',
#  'kinaabe57',
#  'elysechu',
#  'sample_work',
#  'emilylam98',
#  'ga_repo.git',
#  'sid25393']

# %% [markdown]
# ### Step 5: Obtain the repo data for every single github username
#
# The repository info for every single public account is available via the following url: `https://api.github.com/users/:the_username/repos`
#
# So basically, `requests.get('https://api.github.com/users/:the_username/repos').json()` will return a list filled with every single repo that user has.
#
# When you're done, you should have a *list of lists*, with each list containing each users individual repos.  It'll look like this:
#
# `[[{user1, repo1}, {user1, repo2}], [{user2, repo1}], [{user3, repo1}, {user3, repo2}, {user3, repo3}], .....]`

# %%
base_url = 'https://api.github.com'

# %%
import requests

# %%
repo_lists = [requests.get(f"{base_url}/users/{username}/repos").json() for username in usernames]

# %%
repo_lists
# Out:
# [[{'id': 72648844,
#    'node_id': 'MDEwOlJlcG9zaXRvcnk3MjY0ODg0NA==',
#    'name': 'cdc-dashboard',
#    'full_name': 'JonathanBechtel/cdc-dashboard',
#    'private': False,
#    'owner': {'login': 'JonathanBechtel',
#     'id': 481696,
#     'node_id': 'MDQ6VXNlcjQ4MTY5Ng==',
#     'avatar_url': 'https://avatars1.githubusercontent.com/u/481696?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/JonathanBechtel',
#     'html_url': 'https://github.com/JonathanBechtel',
#     'followers_url': 'https://api.github.com/users/JonathanBechtel/followers',
#     'following_url': 'https://api.github.com/users/JonathanBechtel/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/JonathanBechtel/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/JonathanBechtel/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/JonathanBechtel/subscriptions',
#     'organizations_url': 'https://api.github.com/users/JonathanBechtel/orgs',
#     'repos_url': 'https://api.github.com/users/JonathanBechtel/repos',
#     'events_url': 'https://api.github.com/users/JonathanBechtel/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/JonathanBechtel/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/JonathanBechtel/cdc-dashboard',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard',
#    'forks_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/forks',
#    'keys_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/teams',
#    'hooks_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/hooks',
#    'issue_events_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/events',
#    'assignees_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/tags',
#    'blobs_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/languages',
#    'stargazers_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/stargazers',
#    'contributors_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/contributors',
#    'subscribers_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/subscribers',
#    'subscription_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/subscription',
#    'commits_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/merges',
#    'archive_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/downloads',
#    'issues_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/deployments',
#    'created_at': '2016-11-02T14:39:37Z',
#    'updated_at': '2016-12-01T23:31:59Z',
#    'pushed_at': '2016-12-13T22:19:38Z',
#    'git_url': 'git://github.com/JonathanBechtel/cdc-dashboard.git',
#    'ssh_url': 'git@github.com:JonathanBechtel/cdc-dashboard.git',
#    'clone_url': 'https://github.com/JonathanBechtel/cdc-dashboard.git',
#    'svn_url': 'https://github.com/JonathanBechtel/cdc-dashboard',
#    'homepage': None,
#    'size': 120,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': 'JavaScript',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'master'},
#   {'id': 235342950,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkyMzUzNDI5NTA=',
#    'name': 'DAT-01-21',
#    'full_name': 'JonathanBechtel/DAT-01-21',
#    'private': False,
#    'owner': {'login': 'JonathanBechtel',
#     'id': 481696,
#     'node_id': 'MDQ6VXNlcjQ4MTY5Ng==',
#     'avatar_url': 'https://avatars1.githubusercontent.com/u/481696?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/JonathanBechtel',
#     'html_url': 'https://github.com/JonathanBechtel',
#     'followers_url': 'https://api.github.com/users/JonathanBechtel/followers',
#     'following_url': 'https://api.github.com/users/JonathanBechtel/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/JonathanBechtel/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/JonathanBechtel/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/JonathanBechtel/subscriptions',
#     'organizations_url': 'https://api.github.com/users/JonathanBechtel/orgs',
#     'repos_url': 'https://api.github.com/users/JonathanBechtel/repos',
#     'events_url': 'https://api.github.com/users/JonathanBechtel/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/JonathanBechtel/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/JonathanBechtel/DAT-01-21',
#    'description': "GitHub Repository for General Assembly's Part-Time Data Science Cohort on 01-21",
#    'fork': False,
#    'url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21',
#    'forks_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/forks',
#    'keys_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/teams',
#    'hooks_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/hooks',
#    'issue_events_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/events',
#    'assignees_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/tags',
#    'blobs_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/languages',
#    'stargazers_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/stargazers',
#    'contributors_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/contributors',
#    'subscribers_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/subscribers',
#    'subscription_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/subscription',
#    'commits_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/merges',
#    'archive_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/downloads',
#    'issues_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/deployments',
#    'created_at': '2020-01-21T12:57:43Z',
#    'updated_at': '2020-01-28T23:17:22Z',
#    'pushed_at': '2020-01-28T23:17:20Z',
#    'git_url': 'git://github.com/JonathanBechtel/DAT-01-21.git',
#    'ssh_url': 'git@github.com:JonathanBechtel/DAT-01-21.git',
#    'clone_url': 'https://github.com/JonathanBechtel/DAT-01-21.git',
#    'svn_url': 'https://github.com/JonathanBechtel/DAT-01-21',
#    'homepage': None,
#    'size': 24951,
#    'stargazers_count': 2,
#    'watchers_count': 2,
#    'language': 'Jupyter Notebook',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'forks_count': 2,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'forks': 2,
#    'open_issues': 0,
#    'watchers': 2,
#    'default_branch': 'master'},
#   {'id': 193928930,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkxOTM5Mjg5MzA=',
#    'name': 'DAT-06-24',
#    'full_name': 'JonathanBechtel/DAT-06-24',
#    'private': False,
#    'owner': {'login': 'JonathanBechtel',
#     'id': 481696,
#     'node_id': 'MDQ6VXNlcjQ4MTY5Ng==',
#     'avatar_url': 'https://avatars1.githubusercontent.com/u/481696?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/JonathanBechtel',
#     'html_url': 'https://github.com/JonathanBechtel',
#     'followers_url': 'https://api.github.com/users/JonathanBechtel/followers',
#     'following_url': 'https://api.github.com/users/JonathanBechtel/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/JonathanBechtel/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/JonathanBechtel/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/JonathanBechtel/subscriptions',
#     'organizations_url': 'https://api.github.com/users/JonathanBechtel/orgs',
#     'repos_url': 'https://api.github.com/users/JonathanBechtel/repos',
#     'events_url': 'https://api.github.com/users/JonathanBechtel/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/JonathanBechtel/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/JonathanBechtel/DAT-06-24',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24',
#    'forks_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/forks',
#    'keys_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/teams',
#    'hooks_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/hooks',
#    'issue_events_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/events',
#    'assignees_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/tags',
#    'blobs_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/languages',
#    'stargazers_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/stargazers',
#    'contributors_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/contributors',
#    'subscribers_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/subscribers',
#    'subscription_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/subscription',
#    'commits_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/merges',
#    'archive_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/downloads',
#    'issues_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/deployments',
#    'created_at': '2019-06-26T15:12:49Z',
#    'updated_at': '2019-09-04T23:58:07Z',
#    'pushed_at': '2019-09-04T23:58:05Z',
#    'git_url': 'git://github.com/JonathanBechtel/DAT-06-24.git',
#    'ssh_url': 'git@github.com:JonathanBechtel/DAT-06-24.git',
#    'clone_url': 'https://github.com/JonathanBechtel/DAT-06-24.git',
#    'svn_url': 'https://github.com/JonathanBechtel/DAT-06-24',
#    'homepage': None,
#    'size': 96775,
#    'stargazers_count': 1,
#    'watchers_count': 1,
#    'language': 'Jupyter Notebook',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'forks_count': 2,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'forks': 2,
#    'open_issues': 0,
#    'watchers': 1,
#    'default_branch': 'master'},
#   {'id': 215089544,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkyMTUwODk1NDQ=',
#    'name': 'DAT-10-14',
#    'full_name': 'JonathanBechtel/DAT-10-14',
#    'private': False,
#    'owner': {'login': 'JonathanBechtel',
#     'id': 481696,
#     'node_id': 'MDQ6VXNlcjQ4MTY5Ng==',
#     'avatar_url': 'https://avatars1.githubusercontent.com/u/481696?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/JonathanBechtel',
#     'html_url': 'https://github.com/JonathanBechtel',
#     'followers_url': 'https://api.github.com/users/JonathanBechtel/followers',
#     'following_url': 'https://api.github.com/users/JonathanBechtel/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/JonathanBechtel/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/JonathanBechtel/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/JonathanBechtel/subscriptions',
#     'organizations_url': 'https://api.github.com/users/JonathanBechtel/orgs',
#     'repos_url': 'https://api.github.com/users/JonathanBechtel/repos',
#     'events_url': 'https://api.github.com/users/JonathanBechtel/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/JonathanBechtel/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/JonathanBechtel/DAT-10-14',
#    'description': 'Master DAT Repo to be used for all class material',
#    'fork': False,
#    'url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14',
#    'forks_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/forks',
#    'keys_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/teams',
#    'hooks_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/hooks',
#    'issue_events_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/events',
#    'assignees_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/tags',
#    'blobs_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/languages',
#    'stargazers_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/stargazers',
#    'contributors_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/contributors',
#    'subscribers_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/subscribers',
#    'subscription_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/subscription',
#    'commits_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/merges',
#    'archive_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/downloads',
#    'issues_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/deployments',
#    'created_at': '2019-10-14T16:13:47Z',
#    'updated_at': '2020-01-08T23:26:22Z',
#    'pushed_at': '2020-01-08T23:26:18Z',
#    'git_url': 'git://github.com/JonathanBechtel/DAT-10-14.git',
#    'ssh_url': 'git@github.com:JonathanBechtel/DAT-10-14.git',
#    'clone_url': 'https://github.com/JonathanBechtel/DAT-10-14.git',
#    'svn_url': 'https://github.com/JonathanBechtel/DAT-10-14',
#    'homepage': None,
#    'size': 99040,
#    'stargazers_count': 1,
#    'watchers_count': 1,
#    'language': 'Jupyter Notebook',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'forks_count': 2,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'forks': 2,
#    'open_issues': 0,
#    'watchers': 1,
#    'default_branch': 'master'},
#   {'id': 165743299,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkxNjU3NDMyOTk=',
#    'name': 'data',
#    'full_name': 'JonathanBechtel/data',
#    'private': False,
#    'owner': {'login': 'JonathanBechtel',
#     'id': 481696,
#     'node_id': 'MDQ6VXNlcjQ4MTY5Ng==',
#     'avatar_url': 'https://avatars1.githubusercontent.com/u/481696?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/JonathanBechtel',
#     'html_url': 'https://github.com/JonathanBechtel',
#     'followers_url': 'https://api.github.com/users/JonathanBechtel/followers',
#     'following_url': 'https://api.github.com/users/JonathanBechtel/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/JonathanBechtel/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/JonathanBechtel/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/JonathanBechtel/subscriptions',
#     'organizations_url': 'https://api.github.com/users/JonathanBechtel/orgs',
#     'repos_url': 'https://api.github.com/users/JonathanBechtel/repos',
#     'events_url': 'https://api.github.com/users/JonathanBechtel/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/JonathanBechtel/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/JonathanBechtel/data',
#    'description': 'Online datasets to use for classes and personal use',
#    'fork': False,
#    'url': 'https://api.github.com/repos/JonathanBechtel/data',
#    'forks_url': 'https://api.github.com/repos/JonathanBechtel/data/forks',
#    'keys_url': 'https://api.github.com/repos/JonathanBechtel/data/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/JonathanBechtel/data/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/JonathanBechtel/data/teams',
#    'hooks_url': 'https://api.github.com/repos/JonathanBechtel/data/hooks',
#    'issue_events_url': 'https://api.github.com/repos/JonathanBechtel/data/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/JonathanBechtel/data/events',
#    'assignees_url': 'https://api.github.com/repos/JonathanBechtel/data/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/JonathanBechtel/data/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/JonathanBechtel/data/tags',
#    'blobs_url': 'https://api.github.com/repos/JonathanBechtel/data/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/JonathanBechtel/data/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/JonathanBechtel/data/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/JonathanBechtel/data/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/JonathanBechtel/data/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/JonathanBechtel/data/languages',
#    'stargazers_url': 'https://api.github.com/repos/JonathanBechtel/data/stargazers',
#    'contributors_url': 'https://api.github.com/repos/JonathanBechtel/data/contributors',
#    'subscribers_url': 'https://api.github.com/repos/JonathanBechtel/data/subscribers',
#    'subscription_url': 'https://api.github.com/repos/JonathanBechtel/data/subscription',
#    'commits_url': 'https://api.github.com/repos/JonathanBechtel/data/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/JonathanBechtel/data/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/JonathanBechtel/data/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/JonathanBechtel/data/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/JonathanBechtel/data/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/JonathanBechtel/data/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/JonathanBechtel/data/merges',
#    'archive_url': 'https://api.github.com/repos/JonathanBechtel/data/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/JonathanBechtel/data/downloads',
#    'issues_url': 'https://api.github.com/repos/JonathanBechtel/data/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/JonathanBechtel/data/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/JonathanBechtel/data/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/JonathanBechtel/data/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/JonathanBechtel/data/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/JonathanBechtel/data/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/JonathanBechtel/data/deployments',
#    'created_at': '2019-01-14T22:09:06Z',
#    'updated_at': '2019-03-07T11:51:12Z',
#    'pushed_at': '2019-03-07T11:51:11Z',
#    'git_url': 'git://github.com/JonathanBechtel/data.git',
#    'ssh_url': 'git@github.com:JonathanBechtel/data.git',
#    'clone_url': 'https://github.com/JonathanBechtel/data.git',
#    'svn_url': 'https://github.com/JonathanBechtel/data',
#    'homepage': None,
#    'size': 64,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': None,
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'master'},
#   {'id': 67149989,
#    'node_id': 'MDEwOlJlcG9zaXRvcnk2NzE0OTk4OQ==',
#    'name': 'Data-Analysis',
#    'full_name': 'JonathanBechtel/Data-Analysis',
#    'private': False,
#    'owner': {'login': 'JonathanBechtel',
#     'id': 481696,
#     'node_id': 'MDQ6VXNlcjQ4MTY5Ng==',
#     'avatar_url': 'https://avatars1.githubusercontent.com/u/481696?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/JonathanBechtel',
#     'html_url': 'https://github.com/JonathanBechtel',
#     'followers_url': 'https://api.github.com/users/JonathanBechtel/followers',
#     'following_url': 'https://api.github.com/users/JonathanBechtel/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/JonathanBechtel/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/JonathanBechtel/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/JonathanBechtel/subscriptions',
#     'organizations_url': 'https://api.github.com/users/JonathanBechtel/orgs',
#     'repos_url': 'https://api.github.com/users/JonathanBechtel/repos',
#     'events_url': 'https://api.github.com/users/JonathanBechtel/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/JonathanBechtel/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/JonathanBechtel/Data-Analysis',
#    'description': 'Kernels used for analyzing different types of data',
#    'fork': False,
#    'url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis',
#    'forks_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/forks',
#    'keys_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/teams',
#    'hooks_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/hooks',
#    'issue_events_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/events',
#    'assignees_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/tags',
#    'blobs_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/languages',
#    'stargazers_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/stargazers',
#    'contributors_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/contributors',
#    'subscribers_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/subscribers',
#    'subscription_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/subscription',
#    'commits_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/merges',
#    'archive_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/downloads',
#    'issues_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/deployments',
#    'created_at': '2016-09-01T16:55:29Z',
#    'updated_at': '2018-01-04T02:09:51Z',
#    'pushed_at': '2016-11-30T16:21:25Z',
#    'git_url': 'git://github.com/JonathanBechtel/Data-Analysis.git',
#    'ssh_url': 'git@github.com:JonathanBechtel/Data-Analysis.git',
#    'clone_url': 'https://github.com/JonathanBechtel/Data-Analysis.git',
#    'svn_url': 'https://github.com/JonathanBechtel/Data-Analysis',
#    'homepage': None,
#    'size': 313,
#    'stargazers_count': 1,
#    'watchers_count': 1,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 1,
#    'default_branch': 'master'},
#   {'id': 186611359,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkxODY2MTEzNTk=',
#    'name': 'easyml',
#    'full_name': 'JonathanBechtel/easyml',
#    'private': False,
#    'owner': {'login': 'JonathanBechtel',
#     'id': 481696,
#     'node_id': 'MDQ6VXNlcjQ4MTY5Ng==',
#     'avatar_url': 'https://avatars1.githubusercontent.com/u/481696?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/JonathanBechtel',
#     'html_url': 'https://github.com/JonathanBechtel',
#     'followers_url': 'https://api.github.com/users/JonathanBechtel/followers',
#     'following_url': 'https://api.github.com/users/JonathanBechtel/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/JonathanBechtel/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/JonathanBechtel/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/JonathanBechtel/subscriptions',
#     'organizations_url': 'https://api.github.com/users/JonathanBechtel/orgs',
#     'repos_url': 'https://api.github.com/users/JonathanBechtel/repos',
#     'events_url': 'https://api.github.com/users/JonathanBechtel/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/JonathanBechtel/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/JonathanBechtel/easyml',
#    'description': 'Handcoded Machine Learning Algorithms in Numpy',
#    'fork': False,
#    'url': 'https://api.github.com/repos/JonathanBechtel/easyml',
#    'forks_url': 'https://api.github.com/repos/JonathanBechtel/easyml/forks',
#    'keys_url': 'https://api.github.com/repos/JonathanBechtel/easyml/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/JonathanBechtel/easyml/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/JonathanBechtel/easyml/teams',
#    'hooks_url': 'https://api.github.com/repos/JonathanBechtel/easyml/hooks',
#    'issue_events_url': 'https://api.github.com/repos/JonathanBechtel/easyml/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/JonathanBechtel/easyml/events',
#    'assignees_url': 'https://api.github.com/repos/JonathanBechtel/easyml/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/JonathanBechtel/easyml/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/JonathanBechtel/easyml/tags',
#    'blobs_url': 'https://api.github.com/repos/JonathanBechtel/easyml/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/JonathanBechtel/easyml/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/JonathanBechtel/easyml/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/JonathanBechtel/easyml/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/JonathanBechtel/easyml/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/JonathanBechtel/easyml/languages',
#    'stargazers_url': 'https://api.github.com/repos/JonathanBechtel/easyml/stargazers',
#    'contributors_url': 'https://api.github.com/repos/JonathanBechtel/easyml/contributors',
#    'subscribers_url': 'https://api.github.com/repos/JonathanBechtel/easyml/subscribers',
#    'subscription_url': 'https://api.github.com/repos/JonathanBechtel/easyml/subscription',
#    'commits_url': 'https://api.github.com/repos/JonathanBechtel/easyml/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/JonathanBechtel/easyml/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/JonathanBechtel/easyml/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/JonathanBechtel/easyml/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/JonathanBechtel/easyml/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/JonathanBechtel/easyml/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/JonathanBechtel/easyml/merges',
#    'archive_url': 'https://api.github.com/repos/JonathanBechtel/easyml/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/JonathanBechtel/easyml/downloads',
#    'issues_url': 'https://api.github.com/repos/JonathanBechtel/easyml/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/JonathanBechtel/easyml/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/JonathanBechtel/easyml/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/JonathanBechtel/easyml/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/JonathanBechtel/easyml/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/JonathanBechtel/easyml/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/JonathanBechtel/easyml/deployments',
#    'created_at': '2019-05-14T11:48:59Z',
#    'updated_at': '2019-06-17T12:58:57Z',
#    'pushed_at': '2019-06-17T12:58:55Z',
#    'git_url': 'git://github.com/JonathanBechtel/easyml.git',
#    'ssh_url': 'git@github.com:JonathanBechtel/easyml.git',
#    'clone_url': 'https://github.com/JonathanBechtel/easyml.git',
#    'svn_url': 'https://github.com/JonathanBechtel/easyml',
#    'homepage': None,
#    'size': 2385,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'mit',
#     'name': 'MIT License',
#     'spdx_id': 'MIT',
#     'url': 'https://api.github.com/licenses/mit',
#     'node_id': 'MDc6TGljZW5zZTEz'},
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'master'},
#   {'id': 77647555,
#    'node_id': 'MDEwOlJlcG9zaXRvcnk3NzY0NzU1NQ==',
#    'name': 'formula-app',
#    'full_name': 'JonathanBechtel/formula-app',
#    'private': False,
#    'owner': {'login': 'JonathanBechtel',
#     'id': 481696,
#     'node_id': 'MDQ6VXNlcjQ4MTY5Ng==',
#     'avatar_url': 'https://avatars1.githubusercontent.com/u/481696?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/JonathanBechtel',
#     'html_url': 'https://github.com/JonathanBechtel',
#     'followers_url': 'https://api.github.com/users/JonathanBechtel/followers',
#     'following_url': 'https://api.github.com/users/JonathanBechtel/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/JonathanBechtel/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/JonathanBechtel/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/JonathanBechtel/subscriptions',
#     'organizations_url': 'https://api.github.com/users/JonathanBechtel/orgs',
#     'repos_url': 'https://api.github.com/users/JonathanBechtel/repos',
#     'events_url': 'https://api.github.com/users/JonathanBechtel/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/JonathanBechtel/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/JonathanBechtel/formula-app',
#    'description': 'Create and manage nutraceutical formulas',
#    'fork': False,
#    'url': 'https://api.github.com/repos/JonathanBechtel/formula-app',
#    'forks_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/forks',
#    'keys_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/teams',
#    'hooks_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/hooks',
#    'issue_events_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/events',
#    'assignees_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/tags',
#    'blobs_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/languages',
#    'stargazers_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/stargazers',
#    'contributors_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/contributors',
#    'subscribers_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/subscribers',
#    'subscription_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/subscription',
#    'commits_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/merges',
#    'archive_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/downloads',
#    'issues_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/deployments',
#    'created_at': '2016-12-30T00:10:24Z',
#    'updated_at': '2017-01-04T15:01:59Z',
#    'pushed_at': '2017-11-21T23:31:12Z',
#    'git_url': 'git://github.com/JonathanBechtel/formula-app.git',
#    'ssh_url': 'git@github.com:JonathanBechtel/formula-app.git',
#    'clone_url': 'https://github.com/JonathanBechtel/formula-app.git',
#    'svn_url': 'https://github.com/JonathanBechtel/formula-app',
#    'homepage': None,
#    'size': 27206,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': 'JavaScript',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'master'},
#   {'id': 29570524,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkyOTU3MDUyNA==',
#    'name': 'formula-calculator',
#    'full_name': 'JonathanBechtel/formula-calculator',
#    'private': False,
#    'owner': {'login': 'JonathanBechtel',
#     'id': 481696,
#     'node_id': 'MDQ6VXNlcjQ4MTY5Ng==',
#     'avatar_url': 'https://avatars1.githubusercontent.com/u/481696?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/JonathanBechtel',
#     'html_url': 'https://github.com/JonathanBechtel',
#     'followers_url': 'https://api.github.com/users/JonathanBechtel/followers',
#     'following_url': 'https://api.github.com/users/JonathanBechtel/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/JonathanBechtel/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/JonathanBechtel/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/JonathanBechtel/subscriptions',
#     'organizations_url': 'https://api.github.com/users/JonathanBechtel/orgs',
#     'repos_url': 'https://api.github.com/users/JonathanBechtel/repos',
#     'events_url': 'https://api.github.com/users/JonathanBechtel/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/JonathanBechtel/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/JonathanBechtel/formula-calculator',
#    'description': 'Source code for javascript program to calculate formula pricing',
#    'fork': False,
#    'url': 'https://api.github.com/repos/JonathanBechtel/formula-calculator',
#    'forks_url': 'https://api.github.com/repos/JonathanBechtel/formula-calculator/forks',
#    'keys_url': 'https://api.github.com/repos/JonathanBechtel/formula-calculator/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/JonathanBechtel/formula-calculator/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/JonathanBechtel/formula-calculator/teams',
#    'hooks_url': 'https://api.github.com/repos/JonathanBechtel/formula-calculator/hooks',
#    'issue_events_url': 'https://api.github.com/repos/JonathanBechtel/formula-calculator/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/JonathanBechtel/formula-calculator/events',
#    'assignees_url': 'https://api.github.com/repos/JonathanBechtel/formula-calculator/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/JonathanBechtel/formula-calculator/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/JonathanBechtel/formula-calculator/tags',
#    'blobs_url': 'https://api.github.com/repos/JonathanBechtel/formula-calculator/git/blobs{/sha}',
# ...
#  {'message': 'Not Found',
#   'documentation_url': 'https://developer.github.com/v3/repos/#list-user-repositories'},
#  [{'id': 115769090,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkxMTU3NjkwOTA=',
#    'name': 'Python-',
#    'full_name': 'sid25393/Python-',
#    'private': False,
#    'owner': {'login': 'sid25393',
#     'id': 28014248,
#     'node_id': 'MDQ6VXNlcjI4MDE0MjQ4',
#     'avatar_url': 'https://avatars1.githubusercontent.com/u/28014248?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/sid25393',
#     'html_url': 'https://github.com/sid25393',
#     'followers_url': 'https://api.github.com/users/sid25393/followers',
#     'following_url': 'https://api.github.com/users/sid25393/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/sid25393/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/sid25393/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/sid25393/subscriptions',
#     'organizations_url': 'https://api.github.com/users/sid25393/orgs',
#     'repos_url': 'https://api.github.com/users/sid25393/repos',
#     'events_url': 'https://api.github.com/users/sid25393/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/sid25393/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/sid25393/Python-',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/sid25393/Python-',
#    'forks_url': 'https://api.github.com/repos/sid25393/Python-/forks',
#    'keys_url': 'https://api.github.com/repos/sid25393/Python-/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/sid25393/Python-/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/sid25393/Python-/teams',
#    'hooks_url': 'https://api.github.com/repos/sid25393/Python-/hooks',
#    'issue_events_url': 'https://api.github.com/repos/sid25393/Python-/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/sid25393/Python-/events',
#    'assignees_url': 'https://api.github.com/repos/sid25393/Python-/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/sid25393/Python-/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/sid25393/Python-/tags',
#    'blobs_url': 'https://api.github.com/repos/sid25393/Python-/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/sid25393/Python-/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/sid25393/Python-/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/sid25393/Python-/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/sid25393/Python-/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/sid25393/Python-/languages',
#    'stargazers_url': 'https://api.github.com/repos/sid25393/Python-/stargazers',
#    'contributors_url': 'https://api.github.com/repos/sid25393/Python-/contributors',
#    'subscribers_url': 'https://api.github.com/repos/sid25393/Python-/subscribers',
#    'subscription_url': 'https://api.github.com/repos/sid25393/Python-/subscription',
#    'commits_url': 'https://api.github.com/repos/sid25393/Python-/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/sid25393/Python-/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/sid25393/Python-/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/sid25393/Python-/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/sid25393/Python-/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/sid25393/Python-/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/sid25393/Python-/merges',
#    'archive_url': 'https://api.github.com/repos/sid25393/Python-/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/sid25393/Python-/downloads',
#    'issues_url': 'https://api.github.com/repos/sid25393/Python-/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/sid25393/Python-/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/sid25393/Python-/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/sid25393/Python-/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/sid25393/Python-/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/sid25393/Python-/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/sid25393/Python-/deployments',
#    'created_at': '2017-12-30T02:46:05Z',
#    'updated_at': '2018-10-04T13:07:29Z',
#    'pushed_at': '2018-01-08T06:11:30Z',
#    'git_url': 'git://github.com/sid25393/Python-.git',
#    'ssh_url': 'git@github.com:sid25393/Python-.git',
#    'clone_url': 'https://github.com/sid25393/Python-.git',
#    'svn_url': 'https://github.com/sid25393/Python-',
#    'homepage': None,
#    'size': 32,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': None,
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'master'},
#   {'id': 89381537,
#    'node_id': 'MDEwOlJlcG9zaXRvcnk4OTM4MTUzNw==',
#    'name': 'R-Programming',
#    'full_name': 'sid25393/R-Programming',
#    'private': False,
#    'owner': {'login': 'sid25393',
#     'id': 28014248,
#     'node_id': 'MDQ6VXNlcjI4MDE0MjQ4',
#     'avatar_url': 'https://avatars1.githubusercontent.com/u/28014248?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/sid25393',
#     'html_url': 'https://github.com/sid25393',
#     'followers_url': 'https://api.github.com/users/sid25393/followers',
#     'following_url': 'https://api.github.com/users/sid25393/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/sid25393/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/sid25393/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/sid25393/subscriptions',
#     'organizations_url': 'https://api.github.com/users/sid25393/orgs',
#     'repos_url': 'https://api.github.com/users/sid25393/repos',
#     'events_url': 'https://api.github.com/users/sid25393/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/sid25393/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/sid25393/R-Programming',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/sid25393/R-Programming',
#    'forks_url': 'https://api.github.com/repos/sid25393/R-Programming/forks',
#    'keys_url': 'https://api.github.com/repos/sid25393/R-Programming/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/sid25393/R-Programming/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/sid25393/R-Programming/teams',
#    'hooks_url': 'https://api.github.com/repos/sid25393/R-Programming/hooks',
#    'issue_events_url': 'https://api.github.com/repos/sid25393/R-Programming/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/sid25393/R-Programming/events',
#    'assignees_url': 'https://api.github.com/repos/sid25393/R-Programming/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/sid25393/R-Programming/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/sid25393/R-Programming/tags',
#    'blobs_url': 'https://api.github.com/repos/sid25393/R-Programming/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/sid25393/R-Programming/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/sid25393/R-Programming/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/sid25393/R-Programming/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/sid25393/R-Programming/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/sid25393/R-Programming/languages',
#    'stargazers_url': 'https://api.github.com/repos/sid25393/R-Programming/stargazers',
#    'contributors_url': 'https://api.github.com/repos/sid25393/R-Programming/contributors',
#    'subscribers_url': 'https://api.github.com/repos/sid25393/R-Programming/subscribers',
#    'subscription_url': 'https://api.github.com/repos/sid25393/R-Programming/subscription',
#    'commits_url': 'https://api.github.com/repos/sid25393/R-Programming/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/sid25393/R-Programming/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/sid25393/R-Programming/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/sid25393/R-Programming/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/sid25393/R-Programming/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/sid25393/R-Programming/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/sid25393/R-Programming/merges',
#    'archive_url': 'https://api.github.com/repos/sid25393/R-Programming/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/sid25393/R-Programming/downloads',
#    'issues_url': 'https://api.github.com/repos/sid25393/R-Programming/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/sid25393/R-Programming/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/sid25393/R-Programming/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/sid25393/R-Programming/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/sid25393/R-Programming/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/sid25393/R-Programming/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/sid25393/R-Programming/deployments',
#    'created_at': '2017-04-25T16:14:08Z',
#    'updated_at': '2018-10-04T13:07:28Z',
#    'pushed_at': '2017-12-30T02:41:43Z',
#    'git_url': 'git://github.com/sid25393/R-Programming.git',
#    'ssh_url': 'git@github.com:sid25393/R-Programming.git',
#    'clone_url': 'https://github.com/sid25393/R-Programming.git',
#    'svn_url': 'https://github.com/sid25393/R-Programming',
#    'homepage': None,
#    'size': 14,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': 'R',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': True,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'master'},
#   {'id': 235472050,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkyMzU0NzIwNTA=',
#    'name': 'sample-repo2',
#    'full_name': 'sid25393/sample-repo2',
#    'private': False,
#    'owner': {'login': 'sid25393',
#     'id': 28014248,
#     'node_id': 'MDQ6VXNlcjI4MDE0MjQ4',
#     'avatar_url': 'https://avatars1.githubusercontent.com/u/28014248?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/sid25393',
#     'html_url': 'https://github.com/sid25393',
#     'followers_url': 'https://api.github.com/users/sid25393/followers',
#     'following_url': 'https://api.github.com/users/sid25393/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/sid25393/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/sid25393/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/sid25393/subscriptions',
#     'organizations_url': 'https://api.github.com/users/sid25393/orgs',
#     'repos_url': 'https://api.github.com/users/sid25393/repos',
#     'events_url': 'https://api.github.com/users/sid25393/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/sid25393/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/sid25393/sample-repo2',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/sid25393/sample-repo2',
#    'forks_url': 'https://api.github.com/repos/sid25393/sample-repo2/forks',
#    'keys_url': 'https://api.github.com/repos/sid25393/sample-repo2/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/sid25393/sample-repo2/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/sid25393/sample-repo2/teams',
#    'hooks_url': 'https://api.github.com/repos/sid25393/sample-repo2/hooks',
#    'issue_events_url': 'https://api.github.com/repos/sid25393/sample-repo2/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/sid25393/sample-repo2/events',
#    'assignees_url': 'https://api.github.com/repos/sid25393/sample-repo2/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/sid25393/sample-repo2/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/sid25393/sample-repo2/tags',
#    'blobs_url': 'https://api.github.com/repos/sid25393/sample-repo2/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/sid25393/sample-repo2/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/sid25393/sample-repo2/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/sid25393/sample-repo2/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/sid25393/sample-repo2/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/sid25393/sample-repo2/languages',
#    'stargazers_url': 'https://api.github.com/repos/sid25393/sample-repo2/stargazers',
#    'contributors_url': 'https://api.github.com/repos/sid25393/sample-repo2/contributors',
#    'subscribers_url': 'https://api.github.com/repos/sid25393/sample-repo2/subscribers',
#    'subscription_url': 'https://api.github.com/repos/sid25393/sample-repo2/subscription',
#    'commits_url': 'https://api.github.com/repos/sid25393/sample-repo2/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/sid25393/sample-repo2/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/sid25393/sample-repo2/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/sid25393/sample-repo2/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/sid25393/sample-repo2/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/sid25393/sample-repo2/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/sid25393/sample-repo2/merges',
#    'archive_url': 'https://api.github.com/repos/sid25393/sample-repo2/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/sid25393/sample-repo2/downloads',
#    'issues_url': 'https://api.github.com/repos/sid25393/sample-repo2/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/sid25393/sample-repo2/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/sid25393/sample-repo2/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/sid25393/sample-repo2/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/sid25393/sample-repo2/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/sid25393/sample-repo2/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/sid25393/sample-repo2/deployments',
#    'created_at': '2020-01-22T00:58:06Z',
#    'updated_at': '2020-01-22T00:58:10Z',
#    'pushed_at': '2020-01-22T00:58:08Z',
#    'git_url': 'git://github.com/sid25393/sample-repo2.git',
#    'ssh_url': 'git@github.com:sid25393/sample-repo2.git',
#    'clone_url': 'https://github.com/sid25393/sample-repo2.git',
#    'svn_url': 'https://github.com/sid25393/sample-repo2',
#    'homepage': None,
#    'size': 1,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': None,
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'master'}]]

# %% [markdown]
# ### Step 6: Create a 'flat' list that contains every unique repo for every single user
#
# When you're done you should have a list that looks like this: `[{user1 repo1}, {user1 repo2}, ....{user n, repo m}]`
#
# Ie, no nested levels like you had before.

# %%
repos = [repo for user in repo_lists for repo in user]
        
repos
# Out:
# [{'id': 72648844,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk3MjY0ODg0NA==',
#   'name': 'cdc-dashboard',
#   'full_name': 'JonathanBechtel/cdc-dashboard',
#   'private': False,
#   'owner': {'login': 'JonathanBechtel',
#    'id': 481696,
#    'node_id': 'MDQ6VXNlcjQ4MTY5Ng==',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/481696?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/JonathanBechtel',
#    'html_url': 'https://github.com/JonathanBechtel',
#    'followers_url': 'https://api.github.com/users/JonathanBechtel/followers',
#    'following_url': 'https://api.github.com/users/JonathanBechtel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/JonathanBechtel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/JonathanBechtel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/JonathanBechtel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/JonathanBechtel/orgs',
#    'repos_url': 'https://api.github.com/users/JonathanBechtel/repos',
#    'events_url': 'https://api.github.com/users/JonathanBechtel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/JonathanBechtel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/JonathanBechtel/cdc-dashboard',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard',
#   'forks_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/forks',
#   'keys_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/teams',
#   'hooks_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/hooks',
#   'issue_events_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/events',
#   'assignees_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/tags',
#   'blobs_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/languages',
#   'stargazers_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/stargazers',
#   'contributors_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/contributors',
#   'subscribers_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/subscribers',
#   'subscription_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/subscription',
#   'commits_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/merges',
#   'archive_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/downloads',
#   'issues_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/JonathanBechtel/cdc-dashboard/deployments',
#   'created_at': '2016-11-02T14:39:37Z',
#   'updated_at': '2016-12-01T23:31:59Z',
#   'pushed_at': '2016-12-13T22:19:38Z',
#   'git_url': 'git://github.com/JonathanBechtel/cdc-dashboard.git',
#   'ssh_url': 'git@github.com:JonathanBechtel/cdc-dashboard.git',
#   'clone_url': 'https://github.com/JonathanBechtel/cdc-dashboard.git',
#   'svn_url': 'https://github.com/JonathanBechtel/cdc-dashboard',
#   'homepage': None,
#   'size': 120,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'JavaScript',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 235342950,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMzUzNDI5NTA=',
#   'name': 'DAT-01-21',
#   'full_name': 'JonathanBechtel/DAT-01-21',
#   'private': False,
#   'owner': {'login': 'JonathanBechtel',
#    'id': 481696,
#    'node_id': 'MDQ6VXNlcjQ4MTY5Ng==',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/481696?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/JonathanBechtel',
#    'html_url': 'https://github.com/JonathanBechtel',
#    'followers_url': 'https://api.github.com/users/JonathanBechtel/followers',
#    'following_url': 'https://api.github.com/users/JonathanBechtel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/JonathanBechtel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/JonathanBechtel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/JonathanBechtel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/JonathanBechtel/orgs',
#    'repos_url': 'https://api.github.com/users/JonathanBechtel/repos',
#    'events_url': 'https://api.github.com/users/JonathanBechtel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/JonathanBechtel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/JonathanBechtel/DAT-01-21',
#   'description': "GitHub Repository for General Assembly's Part-Time Data Science Cohort on 01-21",
#   'fork': False,
#   'url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21',
#   'forks_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/forks',
#   'keys_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/teams',
#   'hooks_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/hooks',
#   'issue_events_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/events',
#   'assignees_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/tags',
#   'blobs_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/languages',
#   'stargazers_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/stargazers',
#   'contributors_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/contributors',
#   'subscribers_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/subscribers',
#   'subscription_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/subscription',
#   'commits_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/merges',
#   'archive_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/downloads',
#   'issues_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/JonathanBechtel/DAT-01-21/deployments',
#   'created_at': '2020-01-21T12:57:43Z',
#   'updated_at': '2020-01-28T23:17:22Z',
#   'pushed_at': '2020-01-28T23:17:20Z',
#   'git_url': 'git://github.com/JonathanBechtel/DAT-01-21.git',
#   'ssh_url': 'git@github.com:JonathanBechtel/DAT-01-21.git',
#   'clone_url': 'https://github.com/JonathanBechtel/DAT-01-21.git',
#   'svn_url': 'https://github.com/JonathanBechtel/DAT-01-21',
#   'homepage': None,
#   'size': 24951,
#   'stargazers_count': 2,
#   'watchers_count': 2,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 2,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 2,
#   'open_issues': 0,
#   'watchers': 2,
#   'default_branch': 'master'},
#  {'id': 193928930,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxOTM5Mjg5MzA=',
#   'name': 'DAT-06-24',
#   'full_name': 'JonathanBechtel/DAT-06-24',
#   'private': False,
#   'owner': {'login': 'JonathanBechtel',
#    'id': 481696,
#    'node_id': 'MDQ6VXNlcjQ4MTY5Ng==',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/481696?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/JonathanBechtel',
#    'html_url': 'https://github.com/JonathanBechtel',
#    'followers_url': 'https://api.github.com/users/JonathanBechtel/followers',
#    'following_url': 'https://api.github.com/users/JonathanBechtel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/JonathanBechtel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/JonathanBechtel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/JonathanBechtel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/JonathanBechtel/orgs',
#    'repos_url': 'https://api.github.com/users/JonathanBechtel/repos',
#    'events_url': 'https://api.github.com/users/JonathanBechtel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/JonathanBechtel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/JonathanBechtel/DAT-06-24',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24',
#   'forks_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/forks',
#   'keys_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/teams',
#   'hooks_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/hooks',
#   'issue_events_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/events',
#   'assignees_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/tags',
#   'blobs_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/languages',
#   'stargazers_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/stargazers',
#   'contributors_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/contributors',
#   'subscribers_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/subscribers',
#   'subscription_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/subscription',
#   'commits_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/merges',
#   'archive_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/downloads',
#   'issues_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/JonathanBechtel/DAT-06-24/deployments',
#   'created_at': '2019-06-26T15:12:49Z',
#   'updated_at': '2019-09-04T23:58:07Z',
#   'pushed_at': '2019-09-04T23:58:05Z',
#   'git_url': 'git://github.com/JonathanBechtel/DAT-06-24.git',
#   'ssh_url': 'git@github.com:JonathanBechtel/DAT-06-24.git',
#   'clone_url': 'https://github.com/JonathanBechtel/DAT-06-24.git',
#   'svn_url': 'https://github.com/JonathanBechtel/DAT-06-24',
#   'homepage': None,
#   'size': 96775,
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 2,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 2,
#   'open_issues': 0,
#   'watchers': 1,
#   'default_branch': 'master'},
#  {'id': 215089544,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMTUwODk1NDQ=',
#   'name': 'DAT-10-14',
#   'full_name': 'JonathanBechtel/DAT-10-14',
#   'private': False,
#   'owner': {'login': 'JonathanBechtel',
#    'id': 481696,
#    'node_id': 'MDQ6VXNlcjQ4MTY5Ng==',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/481696?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/JonathanBechtel',
#    'html_url': 'https://github.com/JonathanBechtel',
#    'followers_url': 'https://api.github.com/users/JonathanBechtel/followers',
#    'following_url': 'https://api.github.com/users/JonathanBechtel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/JonathanBechtel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/JonathanBechtel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/JonathanBechtel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/JonathanBechtel/orgs',
#    'repos_url': 'https://api.github.com/users/JonathanBechtel/repos',
#    'events_url': 'https://api.github.com/users/JonathanBechtel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/JonathanBechtel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/JonathanBechtel/DAT-10-14',
#   'description': 'Master DAT Repo to be used for all class material',
#   'fork': False,
#   'url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14',
#   'forks_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/forks',
#   'keys_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/teams',
#   'hooks_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/hooks',
#   'issue_events_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/events',
#   'assignees_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/tags',
#   'blobs_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/languages',
#   'stargazers_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/stargazers',
#   'contributors_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/contributors',
#   'subscribers_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/subscribers',
#   'subscription_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/subscription',
#   'commits_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/merges',
#   'archive_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/downloads',
#   'issues_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/JonathanBechtel/DAT-10-14/deployments',
#   'created_at': '2019-10-14T16:13:47Z',
#   'updated_at': '2020-01-08T23:26:22Z',
#   'pushed_at': '2020-01-08T23:26:18Z',
#   'git_url': 'git://github.com/JonathanBechtel/DAT-10-14.git',
#   'ssh_url': 'git@github.com:JonathanBechtel/DAT-10-14.git',
#   'clone_url': 'https://github.com/JonathanBechtel/DAT-10-14.git',
#   'svn_url': 'https://github.com/JonathanBechtel/DAT-10-14',
#   'homepage': None,
#   'size': 99040,
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 2,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 2,
#   'open_issues': 0,
#   'watchers': 1,
#   'default_branch': 'master'},
#  {'id': 165743299,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxNjU3NDMyOTk=',
#   'name': 'data',
#   'full_name': 'JonathanBechtel/data',
#   'private': False,
#   'owner': {'login': 'JonathanBechtel',
#    'id': 481696,
#    'node_id': 'MDQ6VXNlcjQ4MTY5Ng==',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/481696?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/JonathanBechtel',
#    'html_url': 'https://github.com/JonathanBechtel',
#    'followers_url': 'https://api.github.com/users/JonathanBechtel/followers',
#    'following_url': 'https://api.github.com/users/JonathanBechtel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/JonathanBechtel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/JonathanBechtel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/JonathanBechtel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/JonathanBechtel/orgs',
#    'repos_url': 'https://api.github.com/users/JonathanBechtel/repos',
#    'events_url': 'https://api.github.com/users/JonathanBechtel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/JonathanBechtel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/JonathanBechtel/data',
#   'description': 'Online datasets to use for classes and personal use',
#   'fork': False,
#   'url': 'https://api.github.com/repos/JonathanBechtel/data',
#   'forks_url': 'https://api.github.com/repos/JonathanBechtel/data/forks',
#   'keys_url': 'https://api.github.com/repos/JonathanBechtel/data/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/JonathanBechtel/data/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/JonathanBechtel/data/teams',
#   'hooks_url': 'https://api.github.com/repos/JonathanBechtel/data/hooks',
#   'issue_events_url': 'https://api.github.com/repos/JonathanBechtel/data/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/JonathanBechtel/data/events',
#   'assignees_url': 'https://api.github.com/repos/JonathanBechtel/data/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/JonathanBechtel/data/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/JonathanBechtel/data/tags',
#   'blobs_url': 'https://api.github.com/repos/JonathanBechtel/data/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/JonathanBechtel/data/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/JonathanBechtel/data/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/JonathanBechtel/data/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/JonathanBechtel/data/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/JonathanBechtel/data/languages',
#   'stargazers_url': 'https://api.github.com/repos/JonathanBechtel/data/stargazers',
#   'contributors_url': 'https://api.github.com/repos/JonathanBechtel/data/contributors',
#   'subscribers_url': 'https://api.github.com/repos/JonathanBechtel/data/subscribers',
#   'subscription_url': 'https://api.github.com/repos/JonathanBechtel/data/subscription',
#   'commits_url': 'https://api.github.com/repos/JonathanBechtel/data/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/JonathanBechtel/data/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/JonathanBechtel/data/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/JonathanBechtel/data/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/JonathanBechtel/data/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/JonathanBechtel/data/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/JonathanBechtel/data/merges',
#   'archive_url': 'https://api.github.com/repos/JonathanBechtel/data/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/JonathanBechtel/data/downloads',
#   'issues_url': 'https://api.github.com/repos/JonathanBechtel/data/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/JonathanBechtel/data/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/JonathanBechtel/data/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/JonathanBechtel/data/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/JonathanBechtel/data/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/JonathanBechtel/data/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/JonathanBechtel/data/deployments',
#   'created_at': '2019-01-14T22:09:06Z',
#   'updated_at': '2019-03-07T11:51:12Z',
#   'pushed_at': '2019-03-07T11:51:11Z',
#   'git_url': 'git://github.com/JonathanBechtel/data.git',
#   'ssh_url': 'git@github.com:JonathanBechtel/data.git',
#   'clone_url': 'https://github.com/JonathanBechtel/data.git',
#   'svn_url': 'https://github.com/JonathanBechtel/data',
#   'homepage': None,
#   'size': 64,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 67149989,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk2NzE0OTk4OQ==',
#   'name': 'Data-Analysis',
#   'full_name': 'JonathanBechtel/Data-Analysis',
#   'private': False,
#   'owner': {'login': 'JonathanBechtel',
#    'id': 481696,
#    'node_id': 'MDQ6VXNlcjQ4MTY5Ng==',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/481696?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/JonathanBechtel',
#    'html_url': 'https://github.com/JonathanBechtel',
#    'followers_url': 'https://api.github.com/users/JonathanBechtel/followers',
#    'following_url': 'https://api.github.com/users/JonathanBechtel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/JonathanBechtel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/JonathanBechtel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/JonathanBechtel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/JonathanBechtel/orgs',
#    'repos_url': 'https://api.github.com/users/JonathanBechtel/repos',
#    'events_url': 'https://api.github.com/users/JonathanBechtel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/JonathanBechtel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/JonathanBechtel/Data-Analysis',
#   'description': 'Kernels used for analyzing different types of data',
#   'fork': False,
#   'url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis',
#   'forks_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/forks',
#   'keys_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/teams',
#   'hooks_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/hooks',
#   'issue_events_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/events',
#   'assignees_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/tags',
#   'blobs_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/languages',
#   'stargazers_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/stargazers',
#   'contributors_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/contributors',
#   'subscribers_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/subscribers',
#   'subscription_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/subscription',
#   'commits_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/merges',
#   'archive_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/downloads',
#   'issues_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/JonathanBechtel/Data-Analysis/deployments',
#   'created_at': '2016-09-01T16:55:29Z',
#   'updated_at': '2018-01-04T02:09:51Z',
#   'pushed_at': '2016-11-30T16:21:25Z',
#   'git_url': 'git://github.com/JonathanBechtel/Data-Analysis.git',
#   'ssh_url': 'git@github.com:JonathanBechtel/Data-Analysis.git',
#   'clone_url': 'https://github.com/JonathanBechtel/Data-Analysis.git',
#   'svn_url': 'https://github.com/JonathanBechtel/Data-Analysis',
#   'homepage': None,
#   'size': 313,
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 1,
#   'default_branch': 'master'},
#  {'id': 186611359,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxODY2MTEzNTk=',
#   'name': 'easyml',
#   'full_name': 'JonathanBechtel/easyml',
#   'private': False,
#   'owner': {'login': 'JonathanBechtel',
#    'id': 481696,
#    'node_id': 'MDQ6VXNlcjQ4MTY5Ng==',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/481696?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/JonathanBechtel',
#    'html_url': 'https://github.com/JonathanBechtel',
#    'followers_url': 'https://api.github.com/users/JonathanBechtel/followers',
#    'following_url': 'https://api.github.com/users/JonathanBechtel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/JonathanBechtel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/JonathanBechtel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/JonathanBechtel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/JonathanBechtel/orgs',
#    'repos_url': 'https://api.github.com/users/JonathanBechtel/repos',
#    'events_url': 'https://api.github.com/users/JonathanBechtel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/JonathanBechtel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/JonathanBechtel/easyml',
#   'description': 'Handcoded Machine Learning Algorithms in Numpy',
#   'fork': False,
#   'url': 'https://api.github.com/repos/JonathanBechtel/easyml',
#   'forks_url': 'https://api.github.com/repos/JonathanBechtel/easyml/forks',
#   'keys_url': 'https://api.github.com/repos/JonathanBechtel/easyml/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/JonathanBechtel/easyml/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/JonathanBechtel/easyml/teams',
#   'hooks_url': 'https://api.github.com/repos/JonathanBechtel/easyml/hooks',
#   'issue_events_url': 'https://api.github.com/repos/JonathanBechtel/easyml/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/JonathanBechtel/easyml/events',
#   'assignees_url': 'https://api.github.com/repos/JonathanBechtel/easyml/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/JonathanBechtel/easyml/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/JonathanBechtel/easyml/tags',
#   'blobs_url': 'https://api.github.com/repos/JonathanBechtel/easyml/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/JonathanBechtel/easyml/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/JonathanBechtel/easyml/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/JonathanBechtel/easyml/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/JonathanBechtel/easyml/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/JonathanBechtel/easyml/languages',
#   'stargazers_url': 'https://api.github.com/repos/JonathanBechtel/easyml/stargazers',
#   'contributors_url': 'https://api.github.com/repos/JonathanBechtel/easyml/contributors',
#   'subscribers_url': 'https://api.github.com/repos/JonathanBechtel/easyml/subscribers',
#   'subscription_url': 'https://api.github.com/repos/JonathanBechtel/easyml/subscription',
#   'commits_url': 'https://api.github.com/repos/JonathanBechtel/easyml/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/JonathanBechtel/easyml/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/JonathanBechtel/easyml/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/JonathanBechtel/easyml/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/JonathanBechtel/easyml/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/JonathanBechtel/easyml/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/JonathanBechtel/easyml/merges',
#   'archive_url': 'https://api.github.com/repos/JonathanBechtel/easyml/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/JonathanBechtel/easyml/downloads',
#   'issues_url': 'https://api.github.com/repos/JonathanBechtel/easyml/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/JonathanBechtel/easyml/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/JonathanBechtel/easyml/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/JonathanBechtel/easyml/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/JonathanBechtel/easyml/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/JonathanBechtel/easyml/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/JonathanBechtel/easyml/deployments',
#   'created_at': '2019-05-14T11:48:59Z',
#   'updated_at': '2019-06-17T12:58:57Z',
#   'pushed_at': '2019-06-17T12:58:55Z',
#   'git_url': 'git://github.com/JonathanBechtel/easyml.git',
#   'ssh_url': 'git@github.com:JonathanBechtel/easyml.git',
#   'clone_url': 'https://github.com/JonathanBechtel/easyml.git',
#   'svn_url': 'https://github.com/JonathanBechtel/easyml',
#   'homepage': None,
#   'size': 2385,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 77647555,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk3NzY0NzU1NQ==',
#   'name': 'formula-app',
#   'full_name': 'JonathanBechtel/formula-app',
#   'private': False,
#   'owner': {'login': 'JonathanBechtel',
#    'id': 481696,
#    'node_id': 'MDQ6VXNlcjQ4MTY5Ng==',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/481696?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/JonathanBechtel',
#    'html_url': 'https://github.com/JonathanBechtel',
#    'followers_url': 'https://api.github.com/users/JonathanBechtel/followers',
#    'following_url': 'https://api.github.com/users/JonathanBechtel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/JonathanBechtel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/JonathanBechtel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/JonathanBechtel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/JonathanBechtel/orgs',
#    'repos_url': 'https://api.github.com/users/JonathanBechtel/repos',
#    'events_url': 'https://api.github.com/users/JonathanBechtel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/JonathanBechtel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/JonathanBechtel/formula-app',
#   'description': 'Create and manage nutraceutical formulas',
#   'fork': False,
#   'url': 'https://api.github.com/repos/JonathanBechtel/formula-app',
#   'forks_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/forks',
#   'keys_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/teams',
#   'hooks_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/hooks',
#   'issue_events_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/events',
#   'assignees_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/tags',
#   'blobs_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/languages',
#   'stargazers_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/stargazers',
#   'contributors_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/contributors',
#   'subscribers_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/subscribers',
#   'subscription_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/subscription',
#   'commits_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/merges',
#   'archive_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/downloads',
#   'issues_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/JonathanBechtel/formula-app/deployments',
#   'created_at': '2016-12-30T00:10:24Z',
#   'updated_at': '2017-01-04T15:01:59Z',
#   'pushed_at': '2017-11-21T23:31:12Z',
#   'git_url': 'git://github.com/JonathanBechtel/formula-app.git',
#   'ssh_url': 'git@github.com:JonathanBechtel/formula-app.git',
#   'clone_url': 'https://github.com/JonathanBechtel/formula-app.git',
#   'svn_url': 'https://github.com/JonathanBechtel/formula-app',
#   'homepage': None,
#   'size': 27206,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'JavaScript',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 29570524,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyOTU3MDUyNA==',
#   'name': 'formula-calculator',
#   'full_name': 'JonathanBechtel/formula-calculator',
#   'private': False,
#   'owner': {'login': 'JonathanBechtel',
#    'id': 481696,
#    'node_id': 'MDQ6VXNlcjQ4MTY5Ng==',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/481696?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/JonathanBechtel',
#    'html_url': 'https://github.com/JonathanBechtel',
#    'followers_url': 'https://api.github.com/users/JonathanBechtel/followers',
#    'following_url': 'https://api.github.com/users/JonathanBechtel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/JonathanBechtel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/JonathanBechtel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/JonathanBechtel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/JonathanBechtel/orgs',
#    'repos_url': 'https://api.github.com/users/JonathanBechtel/repos',
#    'events_url': 'https://api.github.com/users/JonathanBechtel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/JonathanBechtel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/JonathanBechtel/formula-calculator',
#   'description': 'Source code for javascript program to calculate formula pricing',
#   'fork': False,
#   'url': 'https://api.github.com/repos/JonathanBechtel/formula-calculator',
#   'forks_url': 'https://api.github.com/repos/JonathanBechtel/formula-calculator/forks',
#   'keys_url': 'https://api.github.com/repos/JonathanBechtel/formula-calculator/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/JonathanBechtel/formula-calculator/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/JonathanBechtel/formula-calculator/teams',
#   'hooks_url': 'https://api.github.com/repos/JonathanBechtel/formula-calculator/hooks',
#   'issue_events_url': 'https://api.github.com/repos/JonathanBechtel/formula-calculator/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/JonathanBechtel/formula-calculator/events',
#   'assignees_url': 'https://api.github.com/repos/JonathanBechtel/formula-calculator/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/JonathanBechtel/formula-calculator/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/JonathanBechtel/formula-calculator/tags',
#   'blobs_url': 'https://api.github.com/repos/JonathanBechtel/formula-calculator/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/JonathanBechtel/formula-calculator/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/JonathanBechtel/formula-calculator/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/JonathanBechtel/formula-calculator/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/JonathanBechtel/formula-calculator/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/JonathanBechtel/formula-calculator/languages',
#   'stargazers_url': 'https://api.github.com/repos/JonathanBechtel/formula-calculator/stargazers',
#   'contributors_url': 'https://api.github.com/repos/JonathanBechtel/formula-calculator/contributors',
# ...
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  'message',
#  'documentation_url',
#  {'id': 115769090,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxMTU3NjkwOTA=',
#   'name': 'Python-',
#   'full_name': 'sid25393/Python-',
#   'private': False,
#   'owner': {'login': 'sid25393',
#    'id': 28014248,
#    'node_id': 'MDQ6VXNlcjI4MDE0MjQ4',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/28014248?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sid25393',
#    'html_url': 'https://github.com/sid25393',
#    'followers_url': 'https://api.github.com/users/sid25393/followers',
#    'following_url': 'https://api.github.com/users/sid25393/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/sid25393/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/sid25393/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/sid25393/subscriptions',
#    'organizations_url': 'https://api.github.com/users/sid25393/orgs',
#    'repos_url': 'https://api.github.com/users/sid25393/repos',
#    'events_url': 'https://api.github.com/users/sid25393/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/sid25393/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/sid25393/Python-',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/sid25393/Python-',
#   'forks_url': 'https://api.github.com/repos/sid25393/Python-/forks',
#   'keys_url': 'https://api.github.com/repos/sid25393/Python-/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/sid25393/Python-/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/sid25393/Python-/teams',
#   'hooks_url': 'https://api.github.com/repos/sid25393/Python-/hooks',
#   'issue_events_url': 'https://api.github.com/repos/sid25393/Python-/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/sid25393/Python-/events',
#   'assignees_url': 'https://api.github.com/repos/sid25393/Python-/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/sid25393/Python-/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/sid25393/Python-/tags',
#   'blobs_url': 'https://api.github.com/repos/sid25393/Python-/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/sid25393/Python-/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/sid25393/Python-/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/sid25393/Python-/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/sid25393/Python-/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/sid25393/Python-/languages',
#   'stargazers_url': 'https://api.github.com/repos/sid25393/Python-/stargazers',
#   'contributors_url': 'https://api.github.com/repos/sid25393/Python-/contributors',
#   'subscribers_url': 'https://api.github.com/repos/sid25393/Python-/subscribers',
#   'subscription_url': 'https://api.github.com/repos/sid25393/Python-/subscription',
#   'commits_url': 'https://api.github.com/repos/sid25393/Python-/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/sid25393/Python-/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/sid25393/Python-/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/sid25393/Python-/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/sid25393/Python-/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/sid25393/Python-/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/sid25393/Python-/merges',
#   'archive_url': 'https://api.github.com/repos/sid25393/Python-/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/sid25393/Python-/downloads',
#   'issues_url': 'https://api.github.com/repos/sid25393/Python-/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/sid25393/Python-/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/sid25393/Python-/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/sid25393/Python-/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/sid25393/Python-/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/sid25393/Python-/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/sid25393/Python-/deployments',
#   'created_at': '2017-12-30T02:46:05Z',
#   'updated_at': '2018-10-04T13:07:29Z',
#   'pushed_at': '2018-01-08T06:11:30Z',
#   'git_url': 'git://github.com/sid25393/Python-.git',
#   'ssh_url': 'git@github.com:sid25393/Python-.git',
#   'clone_url': 'https://github.com/sid25393/Python-.git',
#   'svn_url': 'https://github.com/sid25393/Python-',
#   'homepage': None,
#   'size': 32,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 89381537,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk4OTM4MTUzNw==',
#   'name': 'R-Programming',
#   'full_name': 'sid25393/R-Programming',
#   'private': False,
#   'owner': {'login': 'sid25393',
#    'id': 28014248,
#    'node_id': 'MDQ6VXNlcjI4MDE0MjQ4',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/28014248?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sid25393',
#    'html_url': 'https://github.com/sid25393',
#    'followers_url': 'https://api.github.com/users/sid25393/followers',
#    'following_url': 'https://api.github.com/users/sid25393/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/sid25393/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/sid25393/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/sid25393/subscriptions',
#    'organizations_url': 'https://api.github.com/users/sid25393/orgs',
#    'repos_url': 'https://api.github.com/users/sid25393/repos',
#    'events_url': 'https://api.github.com/users/sid25393/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/sid25393/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/sid25393/R-Programming',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/sid25393/R-Programming',
#   'forks_url': 'https://api.github.com/repos/sid25393/R-Programming/forks',
#   'keys_url': 'https://api.github.com/repos/sid25393/R-Programming/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/sid25393/R-Programming/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/sid25393/R-Programming/teams',
#   'hooks_url': 'https://api.github.com/repos/sid25393/R-Programming/hooks',
#   'issue_events_url': 'https://api.github.com/repos/sid25393/R-Programming/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/sid25393/R-Programming/events',
#   'assignees_url': 'https://api.github.com/repos/sid25393/R-Programming/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/sid25393/R-Programming/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/sid25393/R-Programming/tags',
#   'blobs_url': 'https://api.github.com/repos/sid25393/R-Programming/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/sid25393/R-Programming/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/sid25393/R-Programming/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/sid25393/R-Programming/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/sid25393/R-Programming/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/sid25393/R-Programming/languages',
#   'stargazers_url': 'https://api.github.com/repos/sid25393/R-Programming/stargazers',
#   'contributors_url': 'https://api.github.com/repos/sid25393/R-Programming/contributors',
#   'subscribers_url': 'https://api.github.com/repos/sid25393/R-Programming/subscribers',
#   'subscription_url': 'https://api.github.com/repos/sid25393/R-Programming/subscription',
#   'commits_url': 'https://api.github.com/repos/sid25393/R-Programming/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/sid25393/R-Programming/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/sid25393/R-Programming/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/sid25393/R-Programming/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/sid25393/R-Programming/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/sid25393/R-Programming/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/sid25393/R-Programming/merges',
#   'archive_url': 'https://api.github.com/repos/sid25393/R-Programming/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/sid25393/R-Programming/downloads',
#   'issues_url': 'https://api.github.com/repos/sid25393/R-Programming/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/sid25393/R-Programming/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/sid25393/R-Programming/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/sid25393/R-Programming/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/sid25393/R-Programming/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/sid25393/R-Programming/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/sid25393/R-Programming/deployments',
#   'created_at': '2017-04-25T16:14:08Z',
#   'updated_at': '2018-10-04T13:07:28Z',
#   'pushed_at': '2017-12-30T02:41:43Z',
#   'git_url': 'git://github.com/sid25393/R-Programming.git',
#   'ssh_url': 'git@github.com:sid25393/R-Programming.git',
#   'clone_url': 'https://github.com/sid25393/R-Programming.git',
#   'svn_url': 'https://github.com/sid25393/R-Programming',
#   'homepage': None,
#   'size': 14,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'R',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': True,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 235472050,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMzU0NzIwNTA=',
#   'name': 'sample-repo2',
#   'full_name': 'sid25393/sample-repo2',
#   'private': False,
#   'owner': {'login': 'sid25393',
#    'id': 28014248,
#    'node_id': 'MDQ6VXNlcjI4MDE0MjQ4',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/28014248?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sid25393',
#    'html_url': 'https://github.com/sid25393',
#    'followers_url': 'https://api.github.com/users/sid25393/followers',
#    'following_url': 'https://api.github.com/users/sid25393/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/sid25393/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/sid25393/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/sid25393/subscriptions',
#    'organizations_url': 'https://api.github.com/users/sid25393/orgs',
#    'repos_url': 'https://api.github.com/users/sid25393/repos',
#    'events_url': 'https://api.github.com/users/sid25393/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/sid25393/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/sid25393/sample-repo2',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/sid25393/sample-repo2',
#   'forks_url': 'https://api.github.com/repos/sid25393/sample-repo2/forks',
#   'keys_url': 'https://api.github.com/repos/sid25393/sample-repo2/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/sid25393/sample-repo2/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/sid25393/sample-repo2/teams',
#   'hooks_url': 'https://api.github.com/repos/sid25393/sample-repo2/hooks',
#   'issue_events_url': 'https://api.github.com/repos/sid25393/sample-repo2/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/sid25393/sample-repo2/events',
#   'assignees_url': 'https://api.github.com/repos/sid25393/sample-repo2/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/sid25393/sample-repo2/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/sid25393/sample-repo2/tags',
#   'blobs_url': 'https://api.github.com/repos/sid25393/sample-repo2/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/sid25393/sample-repo2/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/sid25393/sample-repo2/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/sid25393/sample-repo2/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/sid25393/sample-repo2/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/sid25393/sample-repo2/languages',
#   'stargazers_url': 'https://api.github.com/repos/sid25393/sample-repo2/stargazers',
#   'contributors_url': 'https://api.github.com/repos/sid25393/sample-repo2/contributors',
#   'subscribers_url': 'https://api.github.com/repos/sid25393/sample-repo2/subscribers',
#   'subscription_url': 'https://api.github.com/repos/sid25393/sample-repo2/subscription',
#   'commits_url': 'https://api.github.com/repos/sid25393/sample-repo2/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/sid25393/sample-repo2/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/sid25393/sample-repo2/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/sid25393/sample-repo2/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/sid25393/sample-repo2/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/sid25393/sample-repo2/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/sid25393/sample-repo2/merges',
#   'archive_url': 'https://api.github.com/repos/sid25393/sample-repo2/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/sid25393/sample-repo2/downloads',
#   'issues_url': 'https://api.github.com/repos/sid25393/sample-repo2/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/sid25393/sample-repo2/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/sid25393/sample-repo2/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/sid25393/sample-repo2/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/sid25393/sample-repo2/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/sid25393/sample-repo2/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/sid25393/sample-repo2/deployments',
#   'created_at': '2020-01-22T00:58:06Z',
#   'updated_at': '2020-01-22T00:58:10Z',
#   'pushed_at': '2020-01-22T00:58:08Z',
#   'git_url': 'git://github.com/sid25393/sample-repo2.git',
#   'ssh_url': 'git@github.com:sid25393/sample-repo2.git',
#   'clone_url': 'https://github.com/sid25393/sample-repo2.git',
#   'svn_url': 'https://github.com/sid25393/sample-repo2',
#   'homepage': None,
#   'size': 1,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'}]

# %% [markdown]
# ### Step 7:  Get information about the name, owner, url, and date of every single repo.
#
# In the dictionary for each repo there are keys called `name`, `login`, `html_url`, and `created_at`.  These are going to populate the values for our different columns.
#
# Values for each one of these keys will need to exist inside their own lists.
#
# **hint:** Notice that the `login` key is nested inside a dictionary that's the value to the `owner` key at the outer level.

# %%
repo_names = [repo['name'] for repo in repos]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-c8fbd7831a36> in <module>
# ----> 1 repo_names = [repo['name'] for repo in repos]
#
# <ipython-input-58-c8fbd7831a36> in <listcomp>(.0)
# ----> 1 repo_names = [repo['name'] for repo in repos]
#
# TypeError: string indices must be integers

# %% [markdown]
# ### Step 8:  Create a dictionary with the data created from step 7
#
# Your final output should look like this:
#
#     `{
#        'Owner': [list with the `login` values],
#        'Name' : [list with the `name` values],
#        'URL'  : [list with the `html_url` values],
#        'Date' : [list with the `created_at` values]
#      }`

# %%
# your answer here

# %% [markdown]
# ### Step 9:  Pass your dictionary into the `pd.dataframe()` method to get your final dataset
#
# Use the `df.head()` method to confirm that you have something that's formatted appropriately.

# %%
# your answer here
