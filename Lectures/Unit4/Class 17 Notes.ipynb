# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor

from sklearn.datasets import load_boston
boston = load_boston()
X = boston.data
y = boston.target

# %%
rf = RandomForestRegressor(random_state=2020)
rf
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators='warn',
#                       n_jobs=None, oob_score=False, random_state=2020,
#                       verbose=0, warm_start=False)

# %%
rf.fit(X, y)
# Random forests just split your data in random, uncorrelated ways
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=2020,
#                       verbose=0, warm_start=False)

# %%
rf.estimators_
# Out:
# [DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        presort=False, random_state=2088543072, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        presort=False, random_state=639299976, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        presort=False, random_state=1603706179, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        presort=False, random_state=522041974, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        presort=False, random_state=41856707, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        presort=False, random_state=944261211, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        presort=False, random_state=1167525501, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        presort=False, random_state=1976532611, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        presort=False, random_state=1447054919, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        presort=False, random_state=681670584, splitter='best')]

# %%
rf.estimators_[0].predict(X[:1])
# Out:
# array([29.4])

# %%
[tree.predict(X[:1]) for tree in rf.estimators_]
# Out:
# [array([29.4]),
#  array([24.]),
#  array([24.]),
#  array([30.1]),
#  array([24.]),
#  array([24.]),
#  array([24.]),
#  array([24.]),
#  array([24.]),
#  array([24.6])]

# %%
np.mean([tree.predict(X[:1]) for tree in rf.estimators_])
# Out:
# 25.21

# %%
rf.predict(X[:1])

# When you predict with the random forest
# you're just predicting each individual decision tree and averaging their values together
# Just takes each individual tree, makes the prediction, and then averages them all together
# Decision trees are weak predictors in useful ways
# Out:
# array([25.21])

# %%
# How do you tune a random forest?

rf.get_params()
# Random forests have some interesting parameters!
# All comes down to how you grow your trees
# Max_depth - how many levels of splitting/branches
# Shallower your trees, the more likely you are to be underfit
# Deeper your trees, the more likely you are to be overfit
# Max Features - maximum number of columns that it accepts. Typically a decimal. .6 is 60% of your columns. More of a top down.
# Min samples per leaf - minimum number of samples that have to be there. More bottom up approach.
# N_estimators - number of trees!
# Out:
# {'bootstrap': True,
#  'criterion': 'mse',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 10,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 2020,
#  'verbose': 0,
#  'warm_start': False}

# %%
rf.score(X, y)
# This is a heavily overfit random forest
# The default value is for the min_samples to be 1. This is not really the best choice
# Out:
# 0.9697998600424886

# %%
# Grid search!
# Like a gigantic cannon
# A great way to exhaustively search parameters

from sklearn.model_selection import GridSearchCV

# %%
# ?GridSearchCV
# Lots of different parameters for GridSearchCV, check em out

# %%
from sklearn.metrics import mean_squared_error, make_scorer

loss_function = make_scorer(mean_squared_error, greater_is_better=False)
# Normally when you do cross validation it returns R2
# Sometimes you'd want to have a loss function
# Greater is better is a default... but you want to the lowest possible mean squared error

# %%
# ?make_scorer

# %%
# Firing out everything and seeing what your best results are
params = {
    'n_estimators': [5, 10, 25, 50],
    'max_features': [.03, 0.4, 0.5, 0.6],
    'min_samples_leaf' : [5, 10, 15]
}

# %%
grid = GridSearchCV(estimator=rf, param_grid=params, scoring=loss_function, cv=5)
# Take our random forest, test out all paramaeters, use our loss function and do 5 fold cross validation

# %%
grid.fit(X,y)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# GridSearchCV(cv=5, error_score='raise-deprecating',
#              estimator=RandomForestRegressor(bootstrap=True, criterion='mse',
#                                              max_depth=None,
#                                              max_features='auto',
#                                              max_leaf_nodes=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimators=10, n_jobs=None,
#                                              oob_score=False, random_state=2020,
#                                              verbose=0, warm_start=False),
#              iid='warn', n_jobs=None,
#              param_grid={'max_features': [0.03, 0.4, 0.5, 0.6],
#                          'min_samples_leaf': [5, 10, 15],
#                          'n_estimators': [5, 10, 25, 50]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=make_scorer(mean_squared_error, greater_is_better=False),
#              verbose=0)

# %%
grid.best_params_
# What combination gave you the best score
# Out:
# {'max_features': 0.6, 'min_samples_leaf': 5, 'n_estimators': 25}

# %%
grid_results = pd.DataFrame(grid.cv_results_)
# A big dictionary
# Useful to turn into a dataframe

# %%
grid_results
# Results from every single permutation
# Effectively create a data set for the fitting of your model to see how things perform under different conditions
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.008188      0.002976         0.000880        0.000192
# 1        0.010707      0.000497         0.000850        0.000061
# 2        0.024029      0.000933         0.001418        0.000109
# 3        0.050411      0.002373         0.002380        0.000129
# 4        0.005582      0.000839         0.000625        0.000031
# 5        0.009899      0.000242         0.001005        0.000300
# 6        0.024342      0.001090         0.001591        0.000302
# 7        0.050071      0.003275         0.002435        0.000289
# 8        0.004995      0.000257         0.000593        0.000020
# 9        0.009674      0.000106         0.000898        0.000120
# 10       0.023389      0.000575         0.001339        0.000047
# 11       0.045418      0.000815         0.002364        0.000341
# 12       0.006339      0.000091         0.000611        0.000028
# 13       0.013695      0.001935         0.000830        0.000036
# 14       0.031178      0.001593         0.001893        0.000632
# 15       0.060968      0.001447         0.002329        0.000093
# 16       0.006349      0.000307         0.000686        0.000154
# 17       0.011788      0.000368         0.000832        0.000077
# 18       0.028886      0.000489         0.001412        0.000071
# 19       0.056321      0.000769         0.002226        0.000091
# 20       0.006105      0.000319         0.000664        0.000112
# 21       0.011237      0.000366         0.000803        0.000052
# 22       0.027551      0.000828         0.001390        0.000123
# 23       0.054738      0.001309         0.002192        0.000060
# 24       0.007204      0.000575         0.000745        0.000079
# 25       0.013126      0.000528         0.000890        0.000123
# 26       0.032124      0.000755         0.001501        0.000126
# 27       0.064187      0.002175         0.002401        0.000106
# 28       0.006747      0.000426         0.000713        0.000199
# 29       0.012463      0.000579         0.000857        0.000060
# 30       0.030330      0.001550         0.001477        0.000224
# 31       0.061274      0.003233         0.002451        0.000257
# 32       0.006035      0.000266         0.000623        0.000058
# 33       0.012295      0.000888         0.000811        0.000021
# 34       0.029344      0.001239         0.001301        0.000024
# 35       0.057487      0.001164         0.002259        0.000149
# 36       0.007156      0.000342         0.000688        0.000154
# 37       0.014505      0.000772         0.000855        0.000030
# 38       0.034454      0.000601         0.001503        0.000102
# 39       0.067979      0.001131         0.002449        0.000149
# 40       0.006984      0.000442         0.000663        0.000076
# 41       0.013149      0.000527         0.000828        0.000058
# 42       0.031930      0.001316         0.001546        0.000103
# 43       0.063335      0.001818         0.002636        0.000421
# 44       0.006367      0.000312         0.000625        0.000067
# 45       0.011791      0.000238         0.000778        0.000006
# 46       0.029409      0.000439         0.001413        0.000148
# 47       0.059468      0.002818         0.002400        0.000461
#
#    param_max_features param_min_samples_leaf param_n_estimators  \
# 0                0.03                      5                  5
# 1                0.03                      5                 10
# 2                0.03                      5                 25
# 3                0.03                      5                 50
# 4                0.03                     10                  5
# 5                0.03                     10                 10
# 6                0.03                     10                 25
# 7                0.03                     10                 50
# 8                0.03                     15                  5
# 9                0.03                     15                 10
# 10               0.03                     15                 25
# 11               0.03                     15                 50
# 12                0.4                      5                  5
# 13                0.4                      5                 10
# 14                0.4                      5                 25
# 15                0.4                      5                 50
# 16                0.4                     10                  5
# 17                0.4                     10                 10
# 18                0.4                     10                 25
# 19                0.4                     10                 50
# 20                0.4                     15                  5
# 21                0.4                     15                 10
# 22                0.4                     15                 25
# 23                0.4                     15                 50
# 24                0.5                      5                  5
# 25                0.5                      5                 10
# 26                0.5                      5                 25
# 27                0.5                      5                 50
# 28                0.5                     10                  5
# 29                0.5                     10                 10
# 30                0.5                     10                 25
# 31                0.5                     10                 50
# 32                0.5                     15                  5
# 33                0.5                     15                 10
# 34                0.5                     15                 25
# 35                0.5                     15                 50
# 36                0.6                      5                  5
# 37                0.6                      5                 10
# 38                0.6                      5                 25
# 39                0.6                      5                 50
# 40                0.6                     10                  5
# 41                0.6                     10                 10
# 42                0.6                     10                 25
# 43                0.6                     10                 50
# 44                0.6                     15                  5
# 45                0.6                     15                 10
# 46                0.6                     15                 25
# 47                0.6                     15                 50
#
#                                                params  split0_test_score  \
# 0   {'max_features': 0.03, 'min_samples_leaf': 5, ...         -18.267616
# 1   {'max_features': 0.03, 'min_samples_leaf': 5, ...         -17.361808
# 2   {'max_features': 0.03, 'min_samples_leaf': 5, ...         -13.680320
# 3   {'max_features': 0.03, 'min_samples_leaf': 5, ...         -15.648012
# 4   {'max_features': 0.03, 'min_samples_leaf': 10,...         -17.399913
# 5   {'max_features': 0.03, 'min_samples_leaf': 10,...         -17.046444
# 6   {'max_features': 0.03, 'min_samples_leaf': 10,...         -17.257105
# 7   {'max_features': 0.03, 'min_samples_leaf': 10,...         -17.151069
# 8   {'max_features': 0.03, 'min_samples_leaf': 15,...         -17.303829
# 9   {'max_features': 0.03, 'min_samples_leaf': 15,...         -17.103864
# 10  {'max_features': 0.03, 'min_samples_leaf': 15,...         -19.635040
# 11  {'max_features': 0.03, 'min_samples_leaf': 15,...         -19.809732
# 12  {'max_features': 0.4, 'min_samples_leaf': 5, '...          -6.966362
# 13  {'max_features': 0.4, 'min_samples_leaf': 5, '...          -7.468959
# 14  {'max_features': 0.4, 'min_samples_leaf': 5, '...          -7.995264
# 15  {'max_features': 0.4, 'min_samples_leaf': 5, '...          -8.120806
# 16  {'max_features': 0.4, 'min_samples_leaf': 10, ...          -9.515717
# 17  {'max_features': 0.4, 'min_samples_leaf': 10, ...          -8.611772
# 18  {'max_features': 0.4, 'min_samples_leaf': 10, ...          -8.214572
# 19  {'max_features': 0.4, 'min_samples_leaf': 10, ...          -8.011197
# 20  {'max_features': 0.4, 'min_samples_leaf': 15, ...         -11.785656
# 21  {'max_features': 0.4, 'min_samples_leaf': 15, ...         -10.267766
# 22  {'max_features': 0.4, 'min_samples_leaf': 15, ...          -8.023012
# 23  {'max_features': 0.4, 'min_samples_leaf': 15, ...          -9.069382
# 24  {'max_features': 0.5, 'min_samples_leaf': 5, '...          -9.356529
# 25  {'max_features': 0.5, 'min_samples_leaf': 5, '...          -8.800115
# 26  {'max_features': 0.5, 'min_samples_leaf': 5, '...          -7.863692
# 27  {'max_features': 0.5, 'min_samples_leaf': 5, '...          -8.402161
# 28  {'max_features': 0.5, 'min_samples_leaf': 10, ...         -10.850557
# 29  {'max_features': 0.5, 'min_samples_leaf': 10, ...         -10.615235
# 30  {'max_features': 0.5, 'min_samples_leaf': 10, ...          -8.965442
# 31  {'max_features': 0.5, 'min_samples_leaf': 10, ...          -8.336824
# 32  {'max_features': 0.5, 'min_samples_leaf': 15, ...         -10.668326
# 33  {'max_features': 0.5, 'min_samples_leaf': 15, ...          -9.687214
# 34  {'max_features': 0.5, 'min_samples_leaf': 15, ...          -8.803620
# 35  {'max_features': 0.5, 'min_samples_leaf': 15, ...          -8.528681
# 36  {'max_features': 0.6, 'min_samples_leaf': 5, '...          -8.596071
# 37  {'max_features': 0.6, 'min_samples_leaf': 5, '...          -9.659311
# 38  {'max_features': 0.6, 'min_samples_leaf': 5, '...          -9.072322
# 39  {'max_features': 0.6, 'min_samples_leaf': 5, '...          -8.653560
# 40  {'max_features': 0.6, 'min_samples_leaf': 10, ...          -9.538137
# 41  {'max_features': 0.6, 'min_samples_leaf': 10, ...         -10.580801
# 42  {'max_features': 0.6, 'min_samples_leaf': 10, ...         -10.025170
# 43  {'max_features': 0.6, 'min_samples_leaf': 10, ...          -9.455479
# 44  {'max_features': 0.6, 'min_samples_leaf': 15, ...         -10.515624
# 45  {'max_features': 0.6, 'min_samples_leaf': 15, ...         -10.605125
# 46  {'max_features': 0.6, 'min_samples_leaf': 15, ...          -9.292617
# 47  {'max_features': 0.6, 'min_samples_leaf': 15, ...          -9.147732
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0          -18.730338         -34.045683         -47.174204
# 1          -24.389460         -45.486862         -51.502005
# 2          -29.596691         -47.567043         -59.980337
# 3          -32.926171         -53.592378         -61.596712
# 4          -21.898561         -45.563424         -52.572051
# 5          -32.844244         -52.427268         -57.968335
# 6          -37.635165         -60.745758         -62.689847
# 7          -39.265197         -65.199490         -62.317082
# 8          -28.165141         -69.201176         -68.155498
# 9          -33.969564         -72.188548         -67.060102
# 10         -42.760066         -77.987431         -70.958172
# 36         -17.236282       -23.081971       15.838300               14
# 37         -15.689954       -20.636571       15.267825                3
# 38         -14.281004       -19.891583       14.164210                1
# 39         -14.692544       -20.122454       13.532295                2
# 40         -15.656569       -24.170725       13.925061               18
# 41         -15.126075       -23.069992       14.509300               13
# 42         -16.003523       -22.022185       13.947286                9
# 43         -15.717116       -21.813606       13.194370                8
# 44         -16.268624       -25.525374       13.954438               27
# 45         -18.409992       -25.775861       15.323221               30
# 46         -18.389827       -24.587128       15.019072               21
# 47         -17.901926       -24.269738       14.521635               19

# %%
grid_results.sort_values(by='rank_test_score')
# The differences between the 1st, 2nd, 3rd, 4th might be a fraction of a percent
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 38       0.034454      0.000601         0.001503        0.000102
# 39       0.067979      0.001131         0.002449        0.000149
# 37       0.014505      0.000772         0.000855        0.000030
# 27       0.064187      0.002175         0.002401        0.000106
# 15       0.060968      0.001447         0.002329        0.000093
# 14       0.031178      0.001593         0.001893        0.000632
# 26       0.032124      0.000755         0.001501        0.000126
# 43       0.063335      0.001818         0.002636        0.000421
# 42       0.031930      0.001316         0.001546        0.000103
# 13       0.013695      0.001935         0.000830        0.000036
# 25       0.013126      0.000528         0.000890        0.000123
# 31       0.061274      0.003233         0.002451        0.000257
# 41       0.013149      0.000527         0.000828        0.000058
# 36       0.007156      0.000342         0.000688        0.000154
# 19       0.056321      0.000769         0.002226        0.000091
# 30       0.030330      0.001550         0.001477        0.000224
# 18       0.028886      0.000489         0.001412        0.000071
# 40       0.006984      0.000442         0.000663        0.000076
# 47       0.059468      0.002818         0.002400        0.000461
# 22       0.027551      0.000828         0.001390        0.000123
# 46       0.029409      0.000439         0.001413        0.000148
# 21       0.011237      0.000366         0.000803        0.000052
# 35       0.057487      0.001164         0.002259        0.000149
# 17       0.011788      0.000368         0.000832        0.000077
# 23       0.054738      0.001309         0.002192        0.000060
# 12       0.006339      0.000091         0.000611        0.000028
# 44       0.006367      0.000312         0.000625        0.000067
# 34       0.029344      0.001239         0.001301        0.000024
# 24       0.007204      0.000575         0.000745        0.000079
# 45       0.011791      0.000238         0.000778        0.000006
# 29       0.012463      0.000579         0.000857        0.000060
# 20       0.006105      0.000319         0.000664        0.000112
# 16       0.006349      0.000307         0.000686        0.000154
# 33       0.012295      0.000888         0.000811        0.000021
# 28       0.006747      0.000426         0.000713        0.000199
# 0        0.008188      0.002976         0.000880        0.000192
# 32       0.006035      0.000266         0.000623        0.000058
# 4        0.005582      0.000839         0.000625        0.000031
# 1        0.010707      0.000497         0.000850        0.000061
# 2        0.024029      0.000933         0.001418        0.000109
# 5        0.009899      0.000242         0.001005        0.000300
# 3        0.050411      0.002373         0.002380        0.000129
# 6        0.024342      0.001090         0.001591        0.000302
# 8        0.004995      0.000257         0.000593        0.000020
# 7        0.050071      0.003275         0.002435        0.000289
# 9        0.009674      0.000106         0.000898        0.000120
# 10       0.023389      0.000575         0.001339        0.000047
# 11       0.045418      0.000815         0.002364        0.000341
#
#    param_max_features param_min_samples_leaf param_n_estimators  \
# 38                0.6                      5                 25
# 39                0.6                      5                 50
# 37                0.6                      5                 10
# 27                0.5                      5                 50
# 15                0.4                      5                 50
# 14                0.4                      5                 25
# 26                0.5                      5                 25
# 43                0.6                     10                 50
# 42                0.6                     10                 25
# 13                0.4                      5                 10
# 25                0.5                      5                 10
# 31                0.5                     10                 50
# 41                0.6                     10                 10
# 36                0.6                      5                  5
# 19                0.4                     10                 50
# 30                0.5                     10                 25
# 18                0.4                     10                 25
# 40                0.6                     10                  5
# 47                0.6                     15                 50
# 22                0.4                     15                 25
# 46                0.6                     15                 25
# 21                0.4                     15                 10
# 35                0.5                     15                 50
# 17                0.4                     10                 10
# 23                0.4                     15                 50
# 12                0.4                      5                  5
# 44                0.6                     15                  5
# 34                0.5                     15                 25
# 24                0.5                      5                  5
# 45                0.6                     15                 10
# 29                0.5                     10                 10
# 20                0.4                     15                  5
# 16                0.4                     10                  5
# 33                0.5                     15                 10
# 28                0.5                     10                  5
# 0                0.03                      5                  5
# 32                0.5                     15                  5
# 4                0.03                     10                  5
# 1                0.03                      5                 10
# 2                0.03                      5                 25
# 5                0.03                     10                 10
# 3                0.03                      5                 50
# 6                0.03                     10                 25
# 8                0.03                     15                  5
# 7                0.03                     10                 50
# 9                0.03                     15                 10
# 10               0.03                     15                 25
# 11               0.03                     15                 50
#
#                                                params  split0_test_score  \
# 38  {'max_features': 0.6, 'min_samples_leaf': 5, '...          -9.072322
# 39  {'max_features': 0.6, 'min_samples_leaf': 5, '...          -8.653560
# 37  {'max_features': 0.6, 'min_samples_leaf': 5, '...          -9.659311
# 27  {'max_features': 0.5, 'min_samples_leaf': 5, '...          -8.402161
# 15  {'max_features': 0.4, 'min_samples_leaf': 5, '...          -8.120806
# 14  {'max_features': 0.4, 'min_samples_leaf': 5, '...          -7.995264
# 26  {'max_features': 0.5, 'min_samples_leaf': 5, '...          -7.863692
# 43  {'max_features': 0.6, 'min_samples_leaf': 10, ...          -9.455479
# 42  {'max_features': 0.6, 'min_samples_leaf': 10, ...         -10.025170
# 13  {'max_features': 0.4, 'min_samples_leaf': 5, '...          -7.468959
# 25  {'max_features': 0.5, 'min_samples_leaf': 5, '...          -8.800115
# 31  {'max_features': 0.5, 'min_samples_leaf': 10, ...          -8.336824
# 41  {'max_features': 0.6, 'min_samples_leaf': 10, ...         -10.580801
# 36  {'max_features': 0.6, 'min_samples_leaf': 5, '...          -8.596071
# 19  {'max_features': 0.4, 'min_samples_leaf': 10, ...          -8.011197
# 30  {'max_features': 0.5, 'min_samples_leaf': 10, ...          -8.965442
# 18  {'max_features': 0.4, 'min_samples_leaf': 10, ...          -8.214572
# 40  {'max_features': 0.6, 'min_samples_leaf': 10, ...          -9.538137
# 47  {'max_features': 0.6, 'min_samples_leaf': 15, ...          -9.147732
# 22  {'max_features': 0.4, 'min_samples_leaf': 15, ...          -8.023012
# 46  {'max_features': 0.6, 'min_samples_leaf': 15, ...          -9.292617
# 21  {'max_features': 0.4, 'min_samples_leaf': 15, ...         -10.267766
# 35  {'max_features': 0.5, 'min_samples_leaf': 15, ...          -8.528681
# 17  {'max_features': 0.4, 'min_samples_leaf': 10, ...          -8.611772
# 23  {'max_features': 0.4, 'min_samples_leaf': 15, ...          -9.069382
# 12  {'max_features': 0.4, 'min_samples_leaf': 5, '...          -6.966362
# 44  {'max_features': 0.6, 'min_samples_leaf': 15, ...         -10.515624
# 34  {'max_features': 0.5, 'min_samples_leaf': 15, ...          -8.803620
# 24  {'max_features': 0.5, 'min_samples_leaf': 5, '...          -9.356529
# 45  {'max_features': 0.6, 'min_samples_leaf': 15, ...         -10.605125
# 29  {'max_features': 0.5, 'min_samples_leaf': 10, ...         -10.615235
# 20  {'max_features': 0.4, 'min_samples_leaf': 15, ...         -11.785656
# 16  {'max_features': 0.4, 'min_samples_leaf': 10, ...          -9.515717
# 33  {'max_features': 0.5, 'min_samples_leaf': 15, ...          -9.687214
# 28  {'max_features': 0.5, 'min_samples_leaf': 10, ...         -10.850557
# 0   {'max_features': 0.03, 'min_samples_leaf': 5, ...         
# 41         -15.126075       -23.069992       14.509300               13
# 36         -17.236282       -23.081971       15.838300               14
# 19         -16.261162       -23.191321       13.710496               15
# 30         -18.809925       -23.515878       14.122861               16
# 18         -16.347963       -23.739369       14.286385               17
# 40         -15.656569       -24.170725       13.925061               18
# 47         -17.901926       -24.269738       14.521635               19
# 22         -16.137543       -24.433918       14.576625               20
# 46         -18.389827       -24.587128       15.019072               21
# 21         -15.295451       -24.651905       14.590806               22
# 35         -17.149038       -24.857005       15.068885               23
# 17         -15.306566       -24.863292       16.759806               24
# 23         -16.317390       -24.899024       14.394819               25
# 12         -18.350933       -25.231733       14.424508               26
# 44         -16.268624       -25.525374       13.954438               27
# 34         -17.650917       -25.565071       15.670109               28
# 24         -20.373635       -25.617522       14.636890               29
# 45         -18.409992       -25.775861       15.323221               30
# 29         -21.580369       -26.384048       15.189278               31
# 20         -17.707451       -26.797724       13.859918               32
# 16         -17.992457       -27.012872       17.786886               33
# 33         -18.624540       -27.303319       15.833389               34
# 28         -23.473943       -27.618388       16.034463               35
# 0          -22.219166       -28.067995       11.117152               36
# 32         -20.615643       -29.766863       17.225014               37
# 4          -20.220367       -31.502936       14.559609               38
# 1          -20.228411       -31.765188       13.949263               39
# 2          -21.011822       -34.326359       17.091962               40
# 5          -20.530270       -36.125532       16.503047               41
# 3          -21.224179       -36.955298       17.905390               42
# 6          -23.200587       -40.260142       18.716737               43
# 8          -21.664445       -40.851389       22.948064               44
# 7          -25.012159       -41.740308       19.321567               45
# 9          -21.027260       -42.220132       23.083054               46
# 10         -23.546365       -46.923378       23.886572               47
# 11         -26.362930       -47.564763       23.054704               48

# %%
grid_results.groupby('param_min_samples_leaf')['mean_test_score'].mean()
# 5 looks like it gives consistently better results
# In real life these numbers are positive.
# Makes it negative automatically to work well with other models.
# Out:
# param_min_samples_leaf
# 5    -24.666358
# 10   -27.497689
# 15   -30.374537
# Name: mean_test_score, dtype: float64

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

pipe = make_pipeline(StandardScaler(), rf)

# %%
pipe
# Out:
# Pipeline(memory=None,
#          steps=[('standardscaler',
#                  StandardScaler(copy=True, with_mean=True, with_std=True)),
#                 ('randomforestregressor',
#                  RandomForestRegressor(bootstrap=True, criterion='mse',
#                                        max_depth=None, max_features='auto',
#                                        max_leaf_nodes=None,
#                                        min_impurity_decrease=0.0,
#                                        min_impurity_split=None,
#                                        min_samples_leaf=1, min_samples_split=2,
#                                        min_weight_fraction_leaf=0.0,
#                                        n_estimators=10, n_jobs=None,
#                                        oob_score=False, random_state=2020,
#                                        verbose=0, warm_start=False))],
#          verbose=False)

# %%
pipe.steps
# You can grid search a pipeline
# You can grid search multiple steps
# Out:
# [('standardscaler', StandardScaler(copy=True, with_mean=True, with_std=True)),
#  ('randomforestregressor',
#   RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                         max_features='auto', max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, n_estimators=10,
#                         n_jobs=None, oob_score=False, random_state=2020,
#                         verbose=0, warm_start=False))]

# %%
params = {
    'randomforestregressor__min_samples_leaf': [5, 10, 15],
    # You type in the name of the step, two underscores, and then the name of the parameter
    'randomforestregressor__max_features': [0.4, 0.5, 0.6]
}

# %%
grid = GridSearchCV(estimator=pipe, param_grid=params, scoring=loss_function, cv=10)
# Once you do that it works exactly the same way

# %%
grid.fit(X,y)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# GridSearchCV(cv=10, error_score='raise-deprecating',
#              estimator=Pipeline(memory=None,
#                                 steps=[('standardscaler',
#                                         StandardScaler(copy=True,
#                                                        with_mean=True,
#                                                        with_std=True)),
#                                        ('randomforestregressor',
#                                         RandomForestRegressor(bootstrap=True,
#                                                               criterion='mse',
#                                                               max_depth=None,
#                                                               max_features='auto',
#                                                               max_leaf_nodes=None,
#                                                               min_impurity_decrease=0.0,
#                                                               min_impurity_split=None,
#                                                               min_...
#                                                               oob_score=False,
#                                                               random_state=2020,
#                                                               verbose=0,
#                                                               warm_start=False))],
#                                 verbose=False),
#              iid='warn', n_jobs=None,
#              param_grid={'randomforestregressor__max_features': [0.4, 0.5, 0.6],
#                          'randomforestregressor__min_samples_leaf': [5, 10,
#                                                                      15]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=make_scorer(mean_squared_error, greater_is_better=False),
#              verbose=0)
